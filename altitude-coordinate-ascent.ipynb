# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression as LR
from matplotlib import pyplot as plt
from tools import *
from sklearn.decomposition import PCA
import plotly.express as px
from sklearn.linear_model import LinearRegression, Ridge, Lasso
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error as MSE
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# # Get Data

# %%
def getObs(n):
    obs = {}
    for i in range(n):
        try:
            df = pd.read_csv(f'rocket-results/{i}.csv')
        except:
            print('Missing', i)
        obs[i] = df
    return obs

# %%
def initializeConfig():
    configs = {}
    with open('sample_list.pkl', 'rb') as f:
        d = pickle.load(f)
    configs.update(d)
    with open('sample_list_100.pkl', 'rb') as f:
        d = pickle.load(f)
    configs.update(d)
    with open('sample_list_200.pkl', 'rb') as f:
        d = pickle.load(f)
    configs.update(d)
    with open('sample_list_300.pkl', 'rb') as f:
        d = pickle.load(f)
    configs.update(d)
    return configs

# %%
config = initializeConfig()
obs = getObs(400)

# %%
data = {}
for i in range(len(config)):
    data[i] = list(config[i]['S'].values()) + list(config[i]['B'].values())
    data[i].append(obs[i].max()['Altitude (ft)'])
    data[i].append(obs[i].mean()['Stability Margin (cal)'])
    data[i].append(obs[i].max()['Time (sec)'])
df = pd.DataFrame.from_dict(data, orient='index')
df.iloc[284]
# Out:
# /var/folders/ff/y3gj2gld0zqfjtq_lhxz03t00000gn/T/ipykernel_30053/2135078581.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data[i].append(obs[i].mean()['Stability Margin (cal)'])
# 0         3.734223
# 1         7.875106
# 2         2.509849
# 3         7.372139
# 4         8.753891
# 5         7.977354
# 6         7.539283
# 7         8.558976
# 8     32187.640000
# 9         5.071216
# 10       99.001530
# Name: 284, dtype: float64

# %%
df = df.rename(columns={0: "Schord", 1: "Sspan", 2: "Ssweep", 3: "Stip", 4: "Bchord", 
                        5: "Bspan", 6: "Bsweep", 7: "Btip", 8: "Altitude", 9: "Stability", 10: "Time"})
df['Schordspan'] = df['Schord'] * df['Sspan']
df['Schordsweep'] = df['Schord'] * df['Ssweep']
df['Schordtip'] = df['Schord'] * df['Stip']
df['Sspansweep'] = df['Sspan'] * df['Ssweep']
df['SSpantip'] = df['Sspan'] * df['Stip']
df['SSweeptip'] = df['Ssweep'] * df['Stip']

df['Bchordspan'] = df['Bchord'] * df['Bspan']
df['Bchordsweep'] = df['Bchord'] * df['Bsweep']
df['Bchordtip'] = df['Bchord'] * df['Btip']
df['Bspansweep'] = df['Bspan'] * df['Bsweep']
df['BSpantip'] = df['Bspan'] * df['Btip']
df['BSweeptip'] = df['Bsweep'] * df['Btip']
alt = df.pop("Altitude")
stab = df.pop("Stability")
time = df.pop("Time")

df.insert(len(df.columns), "Altitude", alt)
df.insert(len(df.columns), "Stability", stab)
df.insert(len(df.columns), "Time", time)
df
# Out:
#        Schord     Sspan    Ssweep      Stip    Bchord     Bspan    Bsweep  \
# 0    9.465233  9.191411  6.313146  6.181568  4.253219  3.362766  2.004250
# 1    5.050903  2.807665  7.250966  4.202998  7.871765  6.329711  3.563606
# 2    8.796076  5.131824  8.469040  8.168441  6.226139  7.792487  6.816335
# 3    5.590219  9.233072  6.352605  8.429602  5.672564  5.705322  5.717624
# 4    2.916229  4.216994  4.711545  6.462613  4.887217  2.638681  9.605809
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  2.608430  3.346465  5.201403  9.166944  6.192108  3.850187  7.960717
# 396  7.801407  2.628427  5.543288  9.133362  7.014197  5.730589  4.246228
# 397  7.364198  8.455093  4.617628  3.805883  4.280772  6.398586  8.552977
# 398  7.094305  2.423077  2.934079  6.637124  4.526698  3.664447  4.901074
# 399  3.451784  3.164933  3.213005  9.450705  8.759146  8.331735  2.206001
#
#          Btip  Schordspan  Schordsweep  ...  SSweeptip  Bchordspan  \
# 0    3.767645   86.998844    59.755399  ...  39.025144   14.302581
# 1    6.148326   14.181241    36.623926  ...  30.475799   49.826002
# 2    8.795342   45.139920    74.494323  ...  69.178850   48.517110
# 3    3.420081   51.614896    35.512459  ...  53.549937   32.363803
# 4    5.234709   12.297724    13.739946  ...  30.448892   12.895807
# ..        ...         ...          ...  ...        ...         ...
# 395  8.586406    8.729021    13.567499  ...  47.680974   23.840776
# 396  6.930445   20.505433    43.245446  ...  50.628851   40.195478
# 397  8.138172   62.264979    34.005123  ...  17.574150   27.390888
# 398  5.327160   17.190049    20.815255  ...  19.473850   16.587847
# 399  6.427374   10.924665    11.090597  ...  30.365158   72.978885
#
#      Bchordsweep  Bchordtip  Bspansweep   BSpantip  BSweeptip      Altitude  \
# 0       8.524515  16.024619    6.739826  12.669711   7.551304      0.004903
# 1      28.051867  48.398181   22.556595  38.917130  21.910210  77117.160000
# 2      42.439452  54.761021   53.116208  68.537590  59.951999  51216.000000
# 3      32.433584  19.400628   32.620884  19.512664  19.554736      0.004691
# 4      46.945675  25.583158   25.346667  13.812727  50.283615      0.004818
# ..           ...        ...         ...        ...        ...           ...
# 395    49.293623  53.167952   30.650253  33.059270  68.353950  70830.750000
# 396    29.783881  48.611503   24.333390  39.715531  29.428252  72485.310000
# 397    36.613344  34.837657   54.726959  52.072793  69.605594      0.000000
# 398    22.185683  24.114444   17.959727  19.521095  26.108803  73446.170000
# 399    19.322682  56.298306   18.379814  53.551178  14.178791  55933.920000
#
#      Stability      Time
# 0    -5.121752    0.0100
# 1     1.278655  154.9973
# 2     5.212006  125.0071
# 3    -2.489141    0.0100
# 4    -4.231226    0.0100
# ..         ...       ...
# 395   1.673402  149.0006
# 396   1.614970  150.9995
# 397  -1.734951    0.0000
# 398   0.853824  150.9995
# 399   2.408665  131.0084
#
# [400 rows x 23 columns]

# %%
# Interaction terms help marginally. 
X_train, X_test = df.iloc[:250, :-15], df.iloc[250:, :-15]

# Stability level 1: cluster into flight time of 20 and 90.
Y_train, Y_test = df.iloc[:250, -1] > 90, df.iloc[250:, -1] > 90

# %%
reg = LR()
reg.fit(X_train, Y_train)
sum(reg.predict(X_test) == Y_test)
print(sum(reg.predict(X_test.iloc[np.where(Y_test == False)]) == Y_test.iloc[np.where(Y_test == False)]) / sum(Y_test == False))
print(sum(reg.predict(X_test.iloc[np.where(Y_test == True)]) == Y_test.iloc[np.where(Y_test == True)]) / sum(Y_test == True))
# Out:
# 0.958904109589041
# 0.8311688311688312

# %%
reg.predict_proba(X_test), Y_test
# Out:
# (array([[2.06790703e-01, 7.93209297e-01],
#         [2.94485528e-02, 9.70551447e-01],
#         [7.34116482e-02, 9.26588352e-01],
#         [6.29730667e-01, 3.70269333e-01],
#         [2.75170480e-02, 9.72482952e-01],
#         [7.98236661e-01, 2.01763339e-01],
#         [9.29147675e-01, 7.08523255e-02],
#         [4.58622148e-01, 5.41377852e-01],
#         [9.98272861e-01, 1.72713898e-03],
#         [9.95574854e-01, 4.42514599e-03],
#         [9.98992777e-01, 1.00722277e-03],
#         [9.01672886e-01, 9.83271141e-02],
#         [5.98911465e-01, 4.01088535e-01],
#         [9.99862438e-01, 1.37562214e-04],
#         [4.63388769e-02, 9.53661123e-01],
#         [2.65241820e-01, 7.34758180e-01],
#         [7.87214229e-02, 9.21278577e-01],
#         [9.99388429e-01, 6.11570868e-04],
#         [9.73115934e-01, 2.68840663e-02],
#         [1.18782769e-01, 8.81217231e-01],
#         [9.24417693e-01, 7.55823066e-02],
#         [9.89045672e-01, 1.09543279e-02],
#         [4.37253994e-01, 5.62746006e-01],
#         [3.30376233e-02, 9.66962377e-01],
#         [7.39641208e-01, 2.60358792e-01],
#         [6.81862656e-02, 9.31813734e-01],
#         [9.73303586e-01, 2.66964141e-02],
#         [9.10825757e-03, 9.90891742e-01],
#         [1.72711985e-01, 8.27288015e-01],
#         [1.60758514e-03, 9.98392415e-01],
#         [8.98963685e-01, 1.01036315e-01],
#         [9.82538701e-02, 9.01746130e-01],
#         [9.99120897e-01, 8.79103317e-04],
#         [6.92886647e-02, 9.30711335e-01],
#         [1.29324586e-01, 8.70675414e-01],
#         [9.97867866e-01, 2.13213375e-03],
#         [8.86887850e-01, 1.13112150e-01],
#         [9.50942261e-01, 4.90577386e-02],
#         [5.60934651e-02, 9.43906535e-01],
#         [1.81311042e-03, 9.98186890e-01],
#         [4.04828976e-01, 5.95171024e-01],
#         [6.72355692e-01, 3.27644308e-01],
#         [2.38231150e-04, 9.99761769e-01],
#         [3.55169116e-04, 9.99644831e-01],
#         [7.22715347e-01, 2.77284653e-01],
#         [8.58430277e-01, 1.41569723e-01],
#         [9.62026474e-01, 3.79735262e-02],
#         [9.98797048e-01, 1.20295181e-03],
#         [9.57292766e-01, 4.27072339e-02],
#         [8.77393224e-01, 1.22606776e-01],
#         [5.06982850e-01, 4.93017150e-01],
#         [9.46912479e-01, 5.30875211e-02],
#         [9.76576998e-01, 2.34230016e-02],
#         [6.87399762e-01, 3.12600238e-01],
#         [9.95000468e-01, 4.99953248e-03],
#         [1.54064913e-01, 8.45935087e-01],
#         [9.98867285e-01, 1.13271468e-03],
#         [1.00741993e-01, 8.99258007e-01],
#         [4.11345542e-02, 9.58865446e-01],
#         [3.26751127e-02, 9.67324887e-01],
#         [2.54819858e-02, 9.74518014e-01],
#         [9.85161973e-01, 1.48380268e-02],
#         [3.93411973e-01, 6.06588027e-01],
#         [4.58337425e-01, 5.41662575e-01],
#         [8.12861765e-01, 1.87138235e-01],
#         [6.16742648e-01, 3.83257352e-01],
#         [9.94732693e-01, 5.26730750e-03],
#         [6.47349369e-01, 3.52650631e-01],
#         [3.84854167e-01, 6.15145833e-01],
#         [7.73538682e-03, 9.92264613e-01],
#         [9.73964375e-01, 2.60356253e-02],
#         [4.44020723e-02, 9.55597928e-01],
#         [1.52267459e-02, 9.84773254e-01],
#         [9.57275006e-01, 4.27249943e-02],
#         [9.70793999e-01, 2.92060015e-02],
#         [4.13097652e-02, 9.58690235e-01],
#         [4.87857162e-01, 5.12142838e-01],
#         [8.22870947e-01, 1.77129053e-01],
#         [3.85254305e-01, 6.14745695e-01],
#         [9.11921479e-01, 8.80785208e-02],
#         [8.18734983e-01, 1.81265017e-01],
#         [9.89521297e-01, 1.04787032e-02],
#         [9.91098993e-01, 8.90100674e-03],
#         [7.91196125e-02, 9.20880387e-01],
#         [9.35947471e-01, 6.40525293e-02],
#         [7.37982628e-01, 2.62017372e-01],
#         [3.44701916e-02, 9.65529808e-01],
#         [6.93569803e-01, 3.06430197e-01],
#         [5.08513343e-02, 9.49148666e-01],
#         [9.97728896e-01, 2.27110352e-03],
#         [9.99662576e-01, 3.37424056e-04],
#         [2.24123240e-01, 7.75876760e-01],
#         [3.19392026e-01, 6.80607974e-01],
#         [1.94138698e-01, 8.05861302e-01],
#         [7.65464697e-03, 9.92345353e-01],
#         [1.81726909e-01, 8.18273091e-01],
#         [7.53103813e-01, 2.46896187e-01],
#         [9.41359625e-01, 5.86403754e-02],
#         [3.19857090e-01, 6.80142910e-01],
#         [9.81902832e-01, 1.80971682e-02],
#         [9.62938059e-01, 3.70619413e-02],
#         [2.35430769e-01, 7.64569231e-01],
#         [1.31748047e-02, 9.86825195e-01],
#         [3.47220615e-03, 9.96527794e-01],
#         [9.58477452e-01, 4.15225485e-02],
#         [9.51170097e-01, 4.88299026e-02],
#         [8.50175794e-01, 1.49824206e-01],
#         [7.63239308e-01, 2.36760692e-01],
#         [4.36124026e-01, 5.63875974e-01],
#         [7.55212459e-01, 2.44787541e-01],
#         [8.50527837e-01, 1.49472163e-01],
#         [6.73732181e-02, 9.32626782e-01],
#         [1.10643629e-01, 8.89356371e-01],
#         [9.31592347e-01, 6.84076535e-02],
#         [6.01088027e-01, 3.98911973e-01],
#         [6.50312483e-01, 3.49687517e-01],
#         [2.31505599e-02, 9.76849440e-01],
#         [1.65019043e-02, 9.83498096e-01],
#         [4.77639879e-02, 9.52236012e-01],
#         [8.48944208e-01, 1.51055792e-01],
#         [8.08466172e-02, 9.19153383e-01],
#         [3.37920698e-01, 6.62079302e-01],
#         [7.75046104e-01, 2.24953896e-01],
#         [5.69266640e-01, 4.30733360e-01],
#         [8.45787995e-01, 1.54212005e-01],
#         [5.96980809e-01, 4.03019191e-01],
#         [7.04720501e-01, 2.95279499e-01],
#         [1.83143327e-01, 8.16856673e-01],
#         [9.98601316e-01, 1.39868396e-03],
#         [3.19958388e-01, 6.80041612e-01],
#         [1.23210203e-01, 8.76789797e-01],
#         [5.48862159e-03, 9.94511378e-01],
#         [4.53302443e-02, 9.54669756e-01],
#         [8.72936134e-01, 1.27063866e-01],
#         [9.14742824e-01, 8.52571759e-02],
#         [8.85075463e-01, 1.14924537e-01],
#         [1.29935592e-02, 9.87006441e-01],
#         [7.11678987e-01, 2.88321013e-01],
#         [3.32299044e-01, 6.67700956e-01],
#         [9.99012708e-01, 9.87291640e-04],
#         [9.71303926e-01, 2.86960745e-02],
#         [9.74203041e-01, 2.57969595e-02],
#         [7.90616226e-01, 2.09383774e-01],
#         [9.08653796e-02, 9.09134620e-01],
#         [8.71560908e-01, 1.28439092e-01],
#         [6.48394104e-01, 3.51605896e-01],
#         [8.86398282e-02, 9.11360172e-01],
#         [8.74591884e-01, 1.25408116e-01],
#         [8.39343466e-01, 1.60656534e-01],
#         [3.19766669e-03, 9.96802333e-01]]),
#  250     True
#  251     True
#  252     True
#  253    False
#  254     True
#         ...
#  395     True
#  396     True
#  397    False
#  398     True
#  399     True
#  Name: Time, Length: 150, dtype: bool)

# %%
# Altitude
lr = LinearRegression()
filtered_df = df[df['Time'] > 90]


X_train, X_test = filtered_df.iloc[:150, :-3], filtered_df.iloc[150:, :-3]

# Stability level 1: cluster into flight time of 20 and 90.
Y_train, Y_test = filtered_df.iloc[:150, -3], filtered_df.iloc[150:, -3]


lr.fit(X_train, Y_train)
lr.score(X_train, Y_train)
# Out:
# 0.9227099971500093

# %%
ridge = Ridge(alpha=10)
ridge.fit(X_train, Y_train)
lasso = Lasso(alpha=100)
lasso.fit(X_train, Y_train)
# Out:
# Lasso(alpha=100)

# %%
print("Training Errors (Lasso, Ridge, Normal)")
np.sqrt([MSE(Y_train, lasso.predict(X_train)), MSE(Y_train, ridge.predict(X_train)), MSE(Y_train, lr.predict(X_train))])
# Out:
# Training Errors (Lasso, Ridge, Normal)
# array([4067.15206808, 4289.22133736, 4028.97177907])

# %%
print('Testing Errors (Lasso, Ridge, Normal)')
#np.sqrt([MSE(Y_test, lasso.predict(X_test)), MSE(Y_test, ridge.predict(X_test)), MSE(Y_test, lr.predict(X_test))])
raw.iloc[idxs]
# Out:
# Testing Errors (Lasso, Ridge, Normal)
#        Schord     Sspan    Ssweep      Stip    Bchord     Bspan    Bsweep  \
# 212  5.259048  8.201739  7.418723  8.216527  2.640339  8.937041  9.653104
# 213  5.556608  5.665979  2.141787  8.167383  6.534285  7.177163  3.075815
# 214  7.736498  6.412773  6.981651  9.384999  7.258333  9.011802  2.222503
# 215  6.513274  3.495698  8.171398  2.001211  8.004495  7.896190  6.976748
# 217  9.498515  2.667657  2.510210  4.382181  4.978264  7.071330  5.616562
# ..        ...       ...       ...       ...       ...       ...       ...
# 91   6.334258  4.689458  8.331010  5.041502  3.633168  6.477348  7.138447
# 94   5.745163  2.524135  4.400265  4.535364  5.006204  8.117043  2.555801
# 95   8.769289  2.628346  6.056928  3.850910  8.635408  6.217285  8.914506
# 96   6.756057  6.367212  6.210186  2.318735  9.237211  8.492059  7.481056
# 98   4.209668  4.827551  8.331124  6.053868  6.454260  7.426452  9.661657
#
#          Btip
# 212  5.900797
# 213  2.232603
# 214  2.632106
# 215  8.157834
# 217  6.388213
# ..        ...
# 91   3.961190
# 94   5.612034
# 95   9.119260
# 96   9.170537
# 98   9.320130
#
# [147 rows x 8 columns]

# %%
poly = PolynomialFeatures(2)
raw = filtered_df.iloc[:,:8]
qr = LinearRegression()
lir = LinearRegression()
idxs = np.array(list(range(50,197)))# + list(range(0, 50)))

ridge = Ridge(alpha=0.6)
ridge.fit(poly.fit_transform(raw.iloc[idxs]), filtered_df.iloc[idxs, -3])
lasso = Lasso(alpha=.2)
lasso.fit(poly.fit_transform(raw.iloc[idxs]), filtered_df.iloc[idxs, -3])
lir.fit(raw.iloc[idxs], filtered_df.iloc[idxs,-3])
qr.fit(poly.fit_transform(raw.iloc[idxs]), filtered_df.iloc[idxs, -3])
print('R2', qr.score(poly.fit_transform(raw.iloc[idxs]), filtered_df.iloc[idxs, -3]))
print('Test RMSE Quad', np.sqrt(MSE(filtered_df.iloc[150:, -3], qr.predict(poly.fit_transform(raw[150:])))))
print('Test RMSE ridge', np.sqrt(MSE(filtered_df.iloc[150:, -3], ridge.predict(poly.fit_transform(raw[150:])))))
print('Test RMSE lasso', np.sqrt(MSE(filtered_df.iloc[0:50, -3], lasso.predict(poly.fit_transform(raw[0:50])))))
print('Test RMSE Linear', np.sqrt(MSE(filtered_df.iloc[0:50, -3], lir.predict((raw[0:50])))))

print('Train RMSE', np.sqrt(MSE(filtered_df.iloc[idxs, -3], qr.predict(poly.fit_transform(raw.iloc[idxs])))))
# Out:
# R2 0.9802095842230094
# Test RMSE Quad 2377.0002169894906
# Test RMSE ridge 1230.9331987762987
# Test RMSE lasso 2055.44657284463
# Test RMSE Linear 4558.176077982448
# Train RMSE 2126.7246957356047
# /Users/alanyu/opt/miniconda3/envs/rocket/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.586e+07, tolerance: 3.360e+06
#   model = cd_fast.enet_coordinate_descent(

# %%
# Should do this from a variety of inital points.
# What if negative ?
# Learning rate
def coordinateAscent(stab_classifier, alt_predictor, initial = [0,0,0,0,0,0,0,0], inc = 0.01, max_iter = 10000, confidence = 0.95):
    '''
    Keep increasing in direction until unstable. 
    '''
    
    x = np.array(initial)
    print('in', x)
    for _ in range(max_iter):
        for i in range(8):
            y = np.array(x)
            y[i] += np.sign(alt_predictor.coef_[i])*inc
            if 10 > y[i] > 3 and stab_classifier.predict_proba(poly.fit_transform([y]))[0,1] > confidence:
                x = np.array(y)
                break
        else:
            print('No more feasible directions at iteration', _, '.')
            break
    return x

# %%
filtered_df.iloc[138]
# Out:
# Schord             3.734223
# Sspan              7.875106
# Ssweep             2.509849
# Stip               7.372139
# Bchord             8.753891
# Bspan              7.977354
# Bsweep             7.539283
# Btip               8.558976
# Schordspan        29.407402
# Schordsweep        9.372334
# Schordtip         27.529212
# Sspansweep        19.765324
# SSpantip          58.056380
# SSweeptip         18.502954
# Bchordspan        69.832887
# Bchordsweep       65.998065
# Bchordtip         74.924351
# Bspansweep        60.143526
# BSpantip          68.277981
# BSweeptip         64.528545
# Altitude       32187.640000
# Stability          5.071216
# Time              99.001530
# Name: 284, dtype: float64

# %%
np.array(samples.iloc[1])
# Out:
# array([4.85018295, 8.39532251, 4.51192896, 6.54405967, 9.2382256 ,
#        8.89249209, 8.39590231, 9.20570753])

# %%
filtered_df.iloc[choices, :8], samples
# Out:
# (       Schord     Sspan    Ssweep      Stip    Bchord     Bspan    Bsweep  \
#  395  2.608430  3.346465  5.201403  9.166944  6.192108  3.850187  7.960717
#  186  4.850183  8.395323  4.511929  6.544060  9.238226  8.892492  8.395902
#  16   5.565645  4.484935  9.236567  7.384820  7.277009  6.544632  2.931606
#  244  4.847887  8.631688  8.610444  2.181684  8.051872  5.556072  2.358074
#  196  6.254379  4.246962  3.976003  7.536317  2.002780  7.896346  2.316434
#  307  3.259887  4.166432  6.110471  9.050886  3.324642  7.487559  9.414183
#  200  3.385068  3.752941  9.547858  2.412589  4.683486  4.715880  3.874262
#  317  3.209788  5.616209  6.283975  7.220497  4.157478  5.305986  7.072609
#  348  4.278144  8.965851  7.574482  8.705158  4.564716  8.731888  8.793370
#  58   8.761546  5.687121  4.663327  9.913209  9.392404  6.941847  2.494271
#
#           Btip
#  395  8.586406
#  186  9.205708
#  16   9.798210
#  244  7.837840
#  196  8.834220
#  307  8.731582
#  200  6.656793
#  317  9.020658
#  348  7.012021
#  58   5.933617  ,
#         Schord     Sspan    Ssweep      Stip    Bchord     Bspan    Bsweep  \
#  395  2.608430  3.346465  5.201403  9.166944  6.192108  3.850187  7.960717
#  186  4.850183  8.395323  4.511929  6.544060  9.238226  8.892492  8.395902
#  16   5.565645  4.484935  9.236567  7.384820  7.277009  6.544632  2.931606
#  244  4.847887  8.631688  8.610444  2.181684  8.051872  5.556072  2.358074
#  196  6.254379  4.246962  3.976003  7.536317  2.002780  7.896346  2.316434
#  307  3.259887  4.166432  6.110471  9.050886  3.324642  7.487559  9.414183
#  200  3.385068  3.752941  9.547858  2.412589  4.683486  4.715880  3.874262
#  317  3.209788  5.616209  6.283975  7.220497  4.157478  5.305986  7.072609
#  348  4.278144  8.965851  7.574482  8.705158  4.564716  8.731888  8.793370
#  58   8.761546  5.687121  4.663327  9.913209  9.392404  6.941847  2.494271
#
#           Btip
#  395  8.586406
#  186  9.205708
#  16   9.798210
#  244  7.837840
#  196  8.834220
#  307  8.731582
#  200  6.656793
#  317  9.020658
#  348  7.012021
#  58   5.933617  )

# %%
import warnings
warnings.filterwarnings("ignore")

#x = coordinateAscent(reg, lr, [4,5,8,8,6,8,7,9], confidence = 0.9)
#x, reg.predict_proba([x]), lr.predict([x])
choices = np.random.choice(len(filtered_df), 10)
samples = filtered_df.iloc[choices, :8]
print(samples)
for i in range(10):
    X0 = np.array(samples.iloc[i])
    #print('here1', X0)
    result = coordinateAscent(q_classifier, lr, X0, confidence = .6)
    #print('here2', X0)
    print(X0, qr.predict(poly.fit_transform([X0])), reg.predict_proba([X0])) #q_classifier.predict_proba(poly.fit_transform([x0])))
    print(qr.predict(poly.fit_transform([result])), result, reg.predict_proba([result]))
    print()
# Out:
#        Schord     Sspan    Ssweep      Stip    Bchord     Bspan    Bsweep  \
# 8    8.074672  3.479253  5.061755  2.201202  8.430403  6.003352  2.080965
# 98   4.209668  4.827551  8.331124  6.053868  6.454260  7.426452  9.661657
# 239  2.188132  2.929254  9.034666  7.787916  3.777422  6.617148  2.369873
# 275  6.803003  4.441887  5.092325  4.497022  8.232802  6.858576  8.440981
# 313  6.461930  2.461362  6.218536  5.257881  7.901328  4.562852  9.386697
# 240  7.068569  2.215733  6.348256  7.886441  7.556871  9.588058  3.485536
# 77   9.371178  8.915615  9.632276  3.661251  9.982313  9.721522  9.922950
# 77   9.371178  8.915615  9.632276  3.661251  9.982313  9.721522  9.922950
# 53   7.805058  2.542296  8.546093  4.073107  7.070326  7.273349  7.698943
# 245  5.715487  7.102609  8.711010  8.826601  8.477324  7.753436  6.884072
#
#          Btip
# 8    3.394916
# 98   9.320130
# 239  4.428782
# 275  8.160722
# 313  4.911477
# 240  3.468907
# 77   7.036977
# 77   7.036977
# 53   2.862030
# 245  6.986278
# in [8.07467226 3.47925257 5.06175521 2.20120157 8.43040333 6.00335154
#  2.08096464 3.39491605]
# No more feasible directions at iteration 2028 .
# [8.07467226 3.47925257 5.06175521 2.20120157 8.43040333 6.00335154
#  2.08096464 3.39491605] [60634.625] [[0.12382169 0.87617831]]
# [74397.125] [3.00467226 3.00925257 9.99175521 2.20120157 3.00040333 9.99335154
#  2.08096464 3.00491605] [[0.00233092 0.99766908]]
#
# in [4.20966833 4.82755058 8.33112372 6.05386772 6.45425962 7.42645223
#  9.66165679 9.32013025]
# No more feasible directions at iteration 2040 .
# [4.20966833 4.82755058 8.33112372 6.05386772 6.45425962 7.42645223
#  9.66165679 9.32013025] [57937.] [[0.04242566 0.95757434]]
# [80714.75] [3.00966833 3.00755058 9.99112372 3.00386772 3.00425962 9.99645223
#  9.99165679 3.00013025] [[0.00809128 0.99190872]]
#
# in [2.18813213 2.9292535  9.03466641 7.78791587 3.77742236 6.61714789
#  2.36987329 4.4287817 ]
# No more feasible directions at iteration 1131 .
# [2.18813213 2.9292535  9.03466641 7.78791587 3.77742236 6.61714789
#  2.36987329 4.4287817 ] [82082.375] [[0.07621508 0.92378492]]
# [76902.125] [2.18813213 2.9292535  9.99466641 3.00791587 3.00742236 9.99714789
#  2.36987329 3.0087817 ] [[0.00223468 0.99776532]]
#
# in [6.80300303 4.44188674 5.09232451 4.49702205 8.23280156 6.85857552
#  8.44098143 8.16072244]
# No more feasible directions at iteration 2671 .
# [6.80300303 4.44188674 5.09232451 4.49702205 8.23280156 6.85857552
#  8.44098143 8.16072244] [53505.125] [[0.06818627 0.93181373]]
# [80793.] [3.00300303 3.00188674 9.99232451 3.00702205 3.00280156 9.99857552
#  9.99098143 3.00072244] [[0.00803972 0.99196028]]
#
# in [6.46193032 2.46136168 6.21853628 5.25788148 7.9013281  4.56285222
#  9.38669684 4.9114767 ]
# No more feasible directions at iteration 2225 .
# [6.46193032 2.46136168 6.21853628 5.25788148 7.9013281  4.56285222
#  9.38669684 4.9114767 ] [85101.375] [[0.45833743 0.54166257]]
# [87976.25] [3.00193032 2.46136168 9.99853628 3.00788148 3.0013281  9.90285222
#  9.99669684 3.0014767 ] [[0.00635943 0.99364057]]
#
# in [7.06856866 2.21573269 6.34825617 7.88644084 7.55687063 9.58805763
#  3.48553571 3.46890728]
# No more feasible directions at iteration 1597 .
# [7.06856866 2.21573269 6.34825617 7.88644084 7.55687063 9.58805763
#  3.48553571 3.46890728] [70692.75] [[0.00117335 0.99882665]]
# [85200.5] [3.00856866 2.21573269 9.99825617 3.00644084 4.63687063 9.58805763
#  3.48553571 3.00890728] [[0.00166805 0.99833195]]
#
# in [9.37117828 8.91561452 9.63227616 3.66125118 9.98231288 9.72152193
#  9.9229497  7.03697657]
# No more feasible directions at iteration 2465 .
# [9.37117828 8.91561452 9.63227616 3.66125118 9.98231288 9.72152193
#  9.9229497  7.03697657] [37191.625] [[0.0246534 0.9753466]]
# [80764.75] [3.00117828 3.00561452 9.99227616 3.00125118 3.00231288 9.99152193
#  9.9929497  3.00697657] [[0.00811607 0.99188393]]
#
# in [9.37117828 8.91561452 9.63227616 3.66125118 9.98231288 9.72152193
#  9.9229497  7.03697657]
# No more feasible directions at iteration 2465 .
# [9.37117828 8.91561452 9.63227616 3.66125118 9.98231288 9.72152193
#  9.9229497  7.03697657] [37191.625] [[0.0246534 0.9753466]]
# [80764.75] [3.00117828 3.00561452 9.99227616 3.00125118 3.00231288 9.99152193
#  9.9929497  3.00697657] [[0.00811607 0.99188393]]
#
# in [7.80505753 2.54229604 8.5460933  4.07310714 7.07032581 7.27334893
#  7.69894332 2.86202971]
# No more feasible directions at iteration 1641 .
# [7.80505753 2.54229604 8.5460933  4.07310714 7.07032581 7.27334893
#  7.69894332 2.86202971] [80545.375] [[0.04424845 0.95575155]]
# [86690.5] [3.00505753 2.54229604 9.9960933  3.00310714 3.00032581 9.99334893
#  9.99894332 2.86202971] [[0.00625128 0.99374872]]
#
# in [5.71548708 7.10260945 8.71101024 8.82660091 8.47732381 7.75343561
#  6.88407201 6.98627806]
# No more feasible directions at iteration 2871 .
# [5.71548708 7.10260945 8.71101024 8.82660091 8.47732381 7.75343561
#  6.88407201 6.98627806] [41477.875] [[0.07955794 0.92044206]]
# [80789.] [3.00548708 3.00260945 9.99101024 3.00660091 3.00732381 9.99343561
#  9.99407201 3.00627806] [[0.00807513 0.99192487]]

# %%
reg.predict([[4,5,8,8,6,8,7,9]])

# %%
np.sign(-3)

# %%
df.max()

# %%
qr.coef_
# Out:
# array([-6.96594266e+14, -1.54643805e+03, -2.06355480e+04,  7.38034342e+03,
#        -3.19684890e+02,  5.35090859e+02, -2.86035997e+03,  5.58915485e+02,
#         1.96125182e+02,  5.07990159e+00,  2.07397768e+02, -7.94708498e+01,
#         5.23132972e+01, -3.01971205e+00, -3.55805849e+00,  8.95297671e-01,
#         7.29560568e+00,  8.90325206e+02, -1.85263007e+02,  3.30525145e+01,
#         9.40290549e+01,  5.21366265e+02, -1.54500926e+02,  3.14041212e+01,
#        -1.70052518e+02,  3.75519267e+01, -5.57080782e+01, -2.14698186e+02,
#         1.28512416e+01, -5.56589464e+00, -6.04397563e+01,  5.55829158e+00,
#         1.53778265e+01,  5.58794760e+00, -1.89868266e+01, -8.32512279e+00,
#        -8.97972084e+01,  2.56453028e+01, -2.13957980e+01,  4.77570650e+01,
#         6.00943454e+01,  3.44119778e+01, -3.43542879e+00, -3.07054111e+01,
#        -3.01965488e+01])

# %%
def coordinateAscentQuad(stab_classifier, alt_predictor, initial = [0,0,0,0,0,0,0,0], inc = 0.0000001, max_iter = 10000, confidence = 0.95):
    '''
    Keep increasing in direction until unstable. 
    '''
    M = {}
    c = 9
    for i in range(8):
        for j in range(i, 8):
            M[(i,j)] = c
            c += 1
    def partials(x):
        grad = []
        coef = alt_predictor.coef_
        for i in range(8):
            g = coef[1 + i]
            for j in range(8):
                if i == j:
                    g += 2*x[i]*coef[M[i,i]]
                else:
                    g += coef[M[min([i,j]), max([i,j])]]*x[j]
            grad.append(g)
        return np.array(grad)
    
    x = initial
    old = qr.predict(poly.fit_transform([x]))
    for _ in range(max_iter):
        #for i in range(8):
        y = np.array(x)
        # y[i] += np.sign(alt_predictor.coef_[i])*inc
        # print(y, partials(x)*inc)
        y += partials(x) * inc
        if np.all(y > 2.5) and y[0] > 2.5 and y[4] > 2.5 and qr.predict(poly.fit_transform([y])) > old:
            nxt = stab_classifier.predict_proba(poly.fit_transform([y]))[0,1]
            if nxt > confidence or np.random.rand() > 0.5:
                if nxt <= confidence:
                    print('Non greedy step')
                x = y[:]
                #print(qr.predict(poly.fit_transform([y])) - old)
                old = qr.predict(poly.fit_transform([y]))
                continue
            else:
                break
        
        print('No more feasible directions at iteration', _, '.', qr.predict(poly.fit_transform([x])) - qr.predict(poly.fit_transform([initial])))
        break
    return x

# %%
x0 = [8.762542, 2.403241, 8.77518, 3.823229, 4.85104, 4.60577, 8.116536, 8.553734]
result = coordinateAscentQuad(reg, qr, x0, confidence = .6)
print(qr.predict(poly.fit_transform([x0])), reg.predict_proba([x0]))#q_classifier.predict_proba(poly.fit_transform([x0])))
qr.predict(poly.fit_transform([result])), result, q_classifier.predict_proba(poly.fit_transform([result]))
# Out:
# No more feasible directions at iteration 0 . [0.]
# [87794.] [[0.33229918 0.66770082]]
# (array([87794.]),
#  [8.762542, 2.403241, 8.77518, 3.823229, 4.85104, 4.60577, 8.116536, 8.553734],
#  array([[0.92912015, 0.07087985]]))

# %%
res = [8.722, 2.0002, 8.837, 3.825, 4.845, 4.5285, 8.1288, 8.54]
#qr.predict(poly.fit_transform([res])), result, q_classifier.predict_proba([res])
df.iloc[:350, :8]
# Out:
#        Schord     Sspan    Ssweep      Stip    Bchord     Bspan    Bsweep  \
# 0    9.465233  9.191411  6.313146  6.181568  4.253219  3.362766  2.004250
# 1    5.050903  2.807665  7.250966  4.202998  7.871765  6.329711  3.563606
# 2    8.796076  5.131824  8.469040  8.168441  6.226139  7.792487  6.816335
# 3    5.590219  9.233072  6.352605  8.429602  5.672564  5.705322  5.717624
# 4    2.916229  4.216994  4.711545  6.462613  4.887217  2.638681  9.605809
# ..        ...       ...       ...       ...       ...       ...       ...
# 345  8.805210  2.507928  8.884587  9.715194  9.885078  3.430887  2.563985
# 346  3.425300  3.120913  6.224504  3.867722  2.054994  5.288580  7.228844
# 347  4.561526  5.292796  4.021472  4.625128  5.743694  4.882127  8.869142
# 348  4.278144  8.965851  7.574482  8.705158  4.564716  8.731888  8.793370
# 349  6.914999  6.577481  2.557393  2.762816  3.651057  4.922490  9.937641
#
#          Btip
# 0    3.767645
# 1    6.148326
# 2    8.795342
# 3    3.420081
# 4    5.234709
# ..        ...
# 345  7.895791
# 346  3.771977
# 347  2.461874
# 348  7.012021
# 349  5.053782
#
# [350 rows x 8 columns]

# %%
# q classifier disagrees a lot with linear. 
q_classifier = LR()
idxs = np.array(list(range(200, 400)) + list(range(100)))

X_train = poly.fit_transform(df.iloc[idxs, :8])
Y_train = df.iloc[idxs, -1] > 90

X_test = poly.fit_transform(df.iloc[100:200, :8])
Y_test = df.iloc[100:200, -1] > 90

q_classifier.fit(X_train, Y_train)

print(sum(q_classifier.predict(X_test) == Y_test))
print(sum(q_classifier.predict(X_test[np.where(Y_test == False)]) == Y_test.iloc[np.where(Y_test == False)]) / sum(Y_test == False))
print(sum(q_classifier.predict(X_test[np.where(Y_test == True)]) == Y_test.iloc[np.where(Y_test == True)]) / sum(Y_test == True))
# Out:
# 93
# 0.9272727272727272
# 0.9333333333333333
# /Users/alanyu/opt/miniconda3/envs/rocket/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
samples = filtered_df.iloc[np.random.choice(len(filtered_df), 10), :8]
for i in range(10):
    X0 = np.array(samples.iloc[i])
    result = coordinateAscentQuad(q_classifier, qr, X0, confidence = .6)
    print(X0, qr.predict(poly.fit_transform([X0])), reg.predict_proba([X0])) #q_classifier.predict_proba(poly.fit_transform([x0])))
    print(qr.predict(poly.fit_transform([result])), result, reg.predict_proba([result]))
    print()
# Out:
# No more feasible directions at iteration 6 . [114.625]
# [8.80520968 2.50792814 8.8845873  9.7151944  9.88507815 3.43088659
#  2.56398478 7.8957911 ] [84950.375] [[0.18172691 0.81827309]]
# [85065.] [8.80453914 2.50006519 8.88594417 9.71480747 9.88491451 3.4287996
#  2.5643135  7.89546474] [[0.18133645 0.81866355]]
#
# No more feasible directions at iteration 0 . [0.]
# [5.49215417 8.26276766 6.21403859 8.44036831 9.6772564  6.78353181
#  2.86848029 5.2141351 ] [35755.875] [[0.31939203 0.68060797]]
# [35755.875] [5.49215417 8.26276766 6.21403859 8.44036831 9.6772564  6.78353181
#  2.86848029 5.2141351 ] [[0.31939203 0.68060797]]
#
# No more feasible directions at iteration 0 . [0.]
# [3.66606175 6.9471738  5.86707696 7.66763302 6.5814646  7.81747032
#  9.11547434 4.66208075] [39312.25] [[0.31995839 0.68004161]]
# [39312.25] [3.66606175 6.9471738  5.86707696 7.66763302 6.5814646  7.81747032
#  9.11547434 4.66208075] [[0.31995839 0.68004161]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.22830359 9.13134253 2.92830428 2.84712976 4.10700216 7.92714511
#  6.64395367 2.77072904] [26470.] [[0.85017579 0.14982421]]
# [26470.] [2.22830359 9.13134253 2.92830428 2.84712976 4.10700216 7.92714511
#  6.64395367 2.77072904] [[0.85017579 0.14982421]]
#
# No more feasible directions at iteration 0 . [0.]
# [5.26580953 4.97583277 9.0757182  7.6018415  2.07617314 9.49516943
#  9.77873692 3.43226772] [57046.] [[0.07604967 0.92395033]]
# [57046.] [5.26580953 4.97583277 9.0757182  7.6018415  2.07617314 9.49516943
#  9.77873692 3.43226772] [[0.07604967 0.92395033]]
#
# No more feasible directions at iteration 0 . [0.]
# [8.04243762 6.54567728 9.72284694 2.59465914 4.73874635 8.58703844
#  3.40612364 8.84626268] [43394.625] [[0.02315056 0.97684944]]
# [43394.625] [8.04243762 6.54567728 9.72284694 2.59465914 4.73874635 8.58703844
#  3.40612364 8.84626268] [[0.02315056 0.97684944]]
#
# No more feasible directions at iteration 0 . [0.]
# [4.31666012 3.86802621 2.32225016 2.61348146 6.03567236 4.31940999
#  5.86434536 9.52098839] [52447.875] [[0.55991851 0.44008149]]
# [52447.875] [4.31666012 3.86802621 2.32225016 2.61348146 6.03567236 4.31940999
#  5.86434536 9.52098839] [[0.55991851 0.44008149]]
#
# No more feasible directions at iteration 0 . [0.]
# [9.64967842 5.9867215  3.45196606 3.87756789 6.47205822 6.1415491
#  2.61811839 4.86949291] [36840.875] [[0.53455729 0.46544271]]
# [36840.875] [9.64967842 5.9867215  3.45196606 3.87756789 6.47205822 6.1415491
#  2.61811839 4.86949291] [[0.53455729 0.46544271]]
#
# No more feasible directions at iteration 0 . [0.]
# [3.21984115 5.39741914 3.06195252 3.71725886 3.17636821 6.49714444
#  4.97751651 3.937595  ] [40994.5] [[0.68760074 0.31239926]]
# [40994.5] [3.21984115 5.39741914 3.06195252 3.71725886 3.17636821 6.49714444
#  4.97751651 3.937595  ] [[0.68760074 0.31239926]]
#
# No more feasible directions at iteration 0 . [0.]
# [4.31666012 3.86802621 2.32225016 2.61348146 6.03567236 4.31940999
#  5.86434536 9.52098839] [52447.875] [[0.55991851 0.44008149]]
# [52447.875] [4.31666012 3.86802621 2.32225016 2.61348146 6.03567236 4.31940999
#  5.86434536 9.52098839] [[0.55991851 0.44008149]]

# %%
np.array(samples.iloc[0])
# Out:
# array([4.73444547e+00, 4.55713543e+00, 4.76768044e+00, 3.43126218e+00,
#        6.18119505e+00, 7.97143628e+00, 6.97046524e+00, 6.40215195e+00,
#        2.15755092e+01, 2.25723231e+01, 1.62451237e+01, 2.17269654e+01,
#        1.56367264e+01, 1.63591616e+01, 4.92730025e+01, 4.30858052e+01,
#        3.95729500e+01, 5.55646194e+01, 5.10343463e+01, 4.46259776e+01,
#        5.08914500e+04, 3.79841953e+00, 1.24006900e+02])

# %%
# linear classifier is not very good ?

# %%
from scipy.optimize import LinearConstraint, NonlinearConstraint, Bounds, minimize
bounds = Bounds([[2.5, np.inf], [2.5, np.inf], [2.5, np.inf]])#, [2.5, np.inf])#, [2.5, np.inf], [2.5, np.inf], [2.5, np.inf])
def stab_constraint(X):
    return q_classifier.predict_proba(poly.fit_transform([X]))[0,1]-0.7
def l0(X):
    return X[0]-7.5
def l1(X):
    return X[1]-3.5
def l2(X):
    return X[2]-3.5
def l3(X):
    return X[3]-3.5
def l4(X):
    return X[4]-7.5
def l5(X):
    return X[5]-3.5
def l6(X):
    return X[6]-3.5
def l7(X):
    return X[7]-3.5

def u0(X):
    return 10-X[0]
def u1(X):
    return 10-X[1]
def u2(X):
    return 10-X[2]
def u3(X):
    return 10-X[3]
def u4(X):
    return 10-X[4]
def u5(X):
    return 10-X[5]
def u6(X):
    return 10-X[6]
def u7(X):
    return 10-X[7]
def objective(X):
    return -qr.predict(poly.fit_transform([X]))[0]
constraint = NonlinearConstraint(stab_constraint, 0.6, np.inf)

# %%
ineq_cons = {'type': 'ineq',
             'fun' : stab_constraint}
L0 = {'type': 'ineq',
             'fun' : l0}
L1 = {'type': 'ineq',
             'fun' : l1}
L2 = {'type': 'ineq',
             'fun' : l2}
L3 = {'type': 'ineq',
             'fun' : l3}
L4 = {'type': 'ineq',
             'fun' : l4}
L5 = {'type': 'ineq',
             'fun' : l5}
L6 = {'type': 'ineq',
             'fun' : l6}
L7 = {'type': 'ineq',
             'fun' : l7}
U0 = {'type': 'ineq',
             'fun' : u0}
U1 = {'type': 'ineq',
             'fun' : u1}
U2 = {'type': 'ineq',
             'fun' : u2}
U3 = {'type': 'ineq',
             'fun' : u3}
U4 = {'type': 'ineq',
             'fun' : u4}
U5 = {'type': 'ineq',
             'fun' : u5}
U6 = {'type': 'ineq',
             'fun' : u6}
U7 = {'type': 'ineq',
             'fun' : u7}
# x = minimize(objective, X0, method='trust-constr', options = {'disp':True}).x#, constraints = [ineq_cons], options={'ftol': 1e-9, 'disp': True})

# %%
print(X0)
res = minimize(objective, X0, method='COBYLA', 
               constraints = [ineq_cons, L0, L1, L2, L3, L4, L5, L6, L7, U0, U1, U2, U3, U4, U5, U6, U7], 
               options = {'verbose':1, 'display':1, 'maxiter':1000}, bounds = bounds)#,constraints = [constraint], options = {'verbose':1})#, bounds = bounds)
res
# Out:
# [4.31666012 3.86802621 2.32225016 2.61348146 6.03567236 4.31940999
#  5.86434536 9.52098839]
#      fun: -82346.125
#    maxcv: 7.883169672595614e-10
#  message: 'Optimization terminated successfully.'
#     nfev: 172
#   status: 1
#  success: True
#        x: array([ 7.5       ,  3.5       , 10.        ,  7.38765915, 10.        ,
#         3.55253104, 10.        ,  3.5       ])

# %%
r = [3.25988046, 4.16648426, 6.11046753, 9.05087259, 3.32468452,
       7.48760038, 9.41419767, 8.73158409]

# %%
qr.predict(poly.fit_transform([r])), qr.predict(poly.fit_transform([X0]))
# Out:
# (array([58798.5]), array([58798.875]))

# %%
X0 = np.array([7.00933451, 6.45751096, 8.41870936, 7.93664641, 6.46337112, 8.07023648, 6.12427831, 5.59915807])
stab_constraint(X0)
# Out:
# 0.999999999520929

# %%
objective(x)
# Out:
# -443163750.0

# %%
np.random.rand(1)
# Out:
# array([0.23559022])

# %%
qr
# Out:
# LinearRegression()

# %%
import torch
class Classifier(torch.nn.Module):

    def __init__(self):
        super(Classifier, self).__init__()

        self.linear1 = torch.nn.Linear(45, 90)
        self.activation1 = torch.nn.ReLU()
        self.linear2 = torch.nn.Linear(90, 60)
        self.activation2 = torch.nn.ReLU()
        self.linear3 = torch.nn.Linear(60, 30)
        self.activation3 = torch.nn.ReLU()
        self.linear4 = torch.nn.Linear(30, 10)
        self.activation4 = torch.nn.ReLU()
        self.linear5 = torch.nn.Linear(10, 1)

    def forward(self, x):
        
        x = self.linear1(x)
        x = self.activation1(x)
        x = self.linear2(x)
        x = self.activation2(x)
        x = self.linear3(x)
        x = self.activation3(x)
        x = self.linear4(x)
        x = self.activation4(x)
        x = self.linear5(x)
        
        return torch.sigmoid(x)

# %%
classif = Classifier()
classif.double()
# Out:
# Classifier(
#   (linear1): Linear(in_features=45, out_features=90, bias=True)
#   (activation1): ReLU()
#   (linear2): Linear(in_features=90, out_features=60, bias=True)
#   (activation2): ReLU()
#   (linear3): Linear(in_features=60, out_features=30, bias=True)
#   (activation3): ReLU()
#   (linear4): Linear(in_features=30, out_features=10, bias=True)
#   (activation4): ReLU()
#   (linear5): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
from torch.utils import data
from torch import nn

def load_arrays(data_arrays, batch_size, train = True):
    dataset = data.TensorDataset(*data_arrays)
    return data.DataLoader(dataset, batch_size, shuffle = train)

# %%
poly = PolynomialFeatures(2)
raw_X = df.iloc[:,:8]
raw_Y = df.iloc[:,-1] > 90
batch_size = 10

train_X = torch.from_numpy(poly.fit_transform(raw_X[:300])).double()
train_Y = torch.from_numpy(np.array([[x] for x in raw_Y[:300]])).double()

test_X = torch.from_numpy(poly.fit_transform(raw_X[300:])).double()
test_Y = torch.from_numpy(np.array([[x] for x in raw_Y[300:]])).double()
data_iter = load_arrays((train_X, train_Y), 10)

# %%
loss = nn.BCELoss()

# %%
trainer = torch.optim.SGD(classif.parameters(), lr=0.01)
num_epochs = 250
for epoch in range(num_epochs):
 
    for X, y in data_iter:
        X.requires_grad = True
        l = loss(classif(X) ,y)

        trainer.zero_grad() #sets gradients to zero

        l.backward() # back propagation

        trainer.step() # parameter update
        
    l = loss(classif(train_X), train_Y)
    if epoch % 50 == 0:
        print(f'epoch {epoch + 1}, loss {l:f}')
        #print(X.grad)
# Out:
# epoch 1, loss 0.433341
# epoch 51, loss 0.068826
# epoch 101, loss 0.015560
# epoch 151, loss 0.009924
# epoch 201, loss 0.008643

# %%
loss(classif(test_X), test_Y)
# Out:
# tensor(0.6437, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)

# %%
sum((classif(test_X) >= 0.5) == test_Y)/len(test_Y)
X0
# Out:
# array([4.31666012, 3.86802621, 2.32225016, 2.61348146, 6.03567236,
#        4.31940999, 5.86434536, 9.52098839])

# %%
def coordinateAscentNN(stab_classifier, alt_predictor, initial = [0,0,0,0,0,0,0,0], inc = 0.0000001, max_iter = 10000, confidence = 0.95):
    '''
    Keep increasing in direction until unstable. 
    '''
    M = {}
    c = 9
    for i in range(8):
        for j in range(i, 8):
            M[(i,j)] = c
            c += 1
    def partials(x):
        grad = []
        coef = alt_predictor.coef_
        for i in range(8):
            g = coef[1 + i]
            for j in range(8):
                if i == j:
                    g += 2*x[i]*coef[M[i,i]]
                else:
                    g += coef[M[min([i,j]), max([i,j])]]*x[j]
            grad.append(g)
        return np.array(grad)
    
    x = initial
    old = qr.predict(poly.fit_transform([x]))
    for _ in range(max_iter):
        #for i in range(8):
        y = np.array(x)
        # y[i] += np.sign(alt_predictor.coef_[i])*inc
        # print(y, partials(x)*inc)
        y += partials(x) * inc
        if np.all(y > 2.5) and y[0] > 2.5 and y[4] > 2.5 and qr.predict(poly.fit_transform([y])) > old:
            nxt = stab_classifier(torch.from_numpy(poly.fit_transform([y])))[0]
            if nxt > confidence or np.random.rand() > 0.5:
                if nxt <= confidence:
                    print('Non greedy step')
                x = y[:]
                #print(qr.predict(poly.fit_transform([y])) - old)
                old = qr.predict(poly.fit_transform([y]))
                continue
            else:
                break
        
        print('No more feasible directions at iteration', _, '.', qr.predict(poly.fit_transform([x])) - qr.predict(poly.fit_transform([initial])))
        break
    return x

# %%
samples = filtered_df.iloc[np.random.choice(len(filtered_df), 197), :8]
best = 0
for i in range(197):
    X0 = np.array(samples.iloc[i])
    result = coordinateAscentNN(classif, qr, X0, confidence = .6)
    print(X0, qr.predict(poly.fit_transform([X0])), reg.predict_proba([X0])) #q_classifier.predict_proba(poly.fit_transform([x0])))
    print(qr.predict(poly.fit_transform([result])), result, reg.predict_proba([result]))
    print()
    best = max(best, qr.predict(poly.fit_transform([result])))
print('BEST', best)
# Out:
# No more feasible directions at iteration 0 . [0.]
# [4.63909766 7.2714982  6.86832483 2.26021714 3.85604358 7.69309272
#  2.95277771 3.86600877] [39688.] [[0.39876633 0.60123367]]
# [39688.] [4.63909766 7.2714982  6.86832483 2.26021714 3.85604358 7.69309272
#  2.95277771 3.86600877] [[0.39876633 0.60123367]]
#
# No more feasible directions at iteration 0 . [0.]
# [3.51324278 3.07721551 6.85920372 6.88783709 9.21928215 6.05656858
#  5.77688879 2.11950605] [76448.125] [[0.11878277 0.88121723]]
# [76448.125] [3.51324278 3.07721551 6.85920372 6.88783709 9.21928215 6.05656858
#  5.77688879 2.11950605] [[0.11878277 0.88121723]]
#
# No more feasible directions at iteration 4 . [1.125]
# [4.24420862 9.87886603 9.85150662 9.96195105 6.38345437 6.98902191
#  3.50112154 8.66333995] [36233.625] [[0.44212496 0.55787504]]
# [36234.75] [4.24433101 9.87899204 9.85165741 9.96170812 6.38350568 6.98938831
#  3.50092648 8.66324658] [[0.44202687 0.55797313]]
#
# No more feasible directions at iteration 0 . [0.]
# [3.44278251 2.09204241 3.67034471 5.5405317  3.84293424 8.57451087
#  9.26924851 2.9502659 ] [77767.] [[0.03994787 0.96005213]]
# [77767.] [3.44278251 2.09204241 3.67034471 5.5405317  3.84293424 8.57451087
#  9.26924851 2.9502659 ] [[0.03994787 0.96005213]]
#
# No more feasible directions at iteration 1838 . [22694.5]
# [6.80300303 4.44188674 5.09232451 4.49702205 8.23280156 6.85857552
#  8.44098143 8.16072244] [53505.125] [[0.06818627 0.93181373]]
# [76199.625] [6.63431945 2.50059664 5.58912049 4.46941097 8.20986987 6.59633647
#  8.51855165 8.07740215] [[0.02675351 0.97324649]]
#
# No more feasible directions at iteration 221 . [140.125]
# [4.85018295 8.39532251 4.51192896 6.54405967 9.2382256  8.89249209
#  8.39590231 9.20570753] [33451.375] [[0.04343894 0.95656106]]
# [33591.5] [4.85547051 8.37734363 4.55114884 6.53635797 9.24170581 8.92486143
#  8.3913594  9.19777169] [[0.0411966 0.9588034]]
#
# No more feasible directions at iteration 426 . [9712.625]
# [3.84330328 3.11903088 8.63367165 8.88974916 8.81972552 3.69938965
#  8.75334237 8.74292895] [83665.375] [[0.36910819 0.63089181]]
# [93378.] [3.79566142 2.50137924 8.74968513 8.85632016 8.81621157 3.58211697
#  8.77061757 8.71038901] [[0.30957528 0.69042472]]
#
# No more feasible directions at iteration 5381 . [33203.875]
# [8.90764272 6.41704043 7.22060632 9.09946315 6.14413484 8.69161938
#  7.7616512  9.18678414] [41375.625] [[0.03327852 0.96672148]]
# [74579.5] [8.59966621 2.50061544 7.98789329 8.84911559 5.99463736 8.24481177
#  7.93009333 8.95767637] [[0.00467726 0.99532274]]
#
# No more feasible directions at iteration 0 . [0.]
# [4.84788685 8.63168772 8.61044395 2.18168394 8.05187205 5.55607202
#  2.35807409 7.83784001] [38127.5] [[0.56895072 0.43104928]]
# [38127.5] [4.84788685 8.63168772 8.61044395 2.18168394 8.05187205 5.55607202
#  2.35807409 7.83784001] [[0.56895072 0.43104928]]
#
# No more feasible directions at iteration 1890 . [27384.875]
# [6.33425839 4.68945772 8.33101047 5.04150204 3.63316753 6.47734776
#  7.13844727 3.96118992] [59929.125] [[0.49760903 0.50239097]]
# [87314.] [6.11971921 2.50045412 8.71108597 5.02656887 3.61158239 6.12222611
#  7.22130503 3.94124938] [[0.26090729 0.73909271]]
#
# No more feasible directions at iteration 1831 . [23699.125]
# [5.5656446  4.48493532 9.23656697 7.38481998 7.2770088  6.54463189
#  2.93160599 9.79820983] [59921.625] [[0.02226226 0.97773774]]
# [83620.75] [5.36685328 2.50079174 9.52842296 7.29651154 7.19439709 6.0944694
#  3.00904263 9.71378249] [[0.0107866 0.9892134]]
#
# No more feasible directions at iteration 0 . [0.]
# [7.09430523 2.42307718 2.93407938 6.63712449 4.52669832 3.66444724
#  4.90107397 5.32715955] [70814.75] [[0.83934347 0.16065653]]
# [70814.75] [7.09430523 2.42307718 2.93407938 6.63712449 4.52669832 3.66444724
#  4.90107397 5.32715955] [[0.83934347 0.16065653]]
#
# No more feasible directions at iteration 2 . [0.625]
# [6.08199065 8.40358411 5.89640539 4.42759739 7.53155837 9.71729336
#  3.73004212 6.38113378] [37853.625] [[0.02548199 0.97451801]]
# [37854.25] [6.08199342 8.40359255 5.89660689 4.42760808 7.5315512  9.71749277
#  3.73002654 6.38114595] [[0.02547543 0.97452457]]
#
# No more feasible directions at iteration 0 . [0.]
# [8.76254164 2.40324077 8.77518014 3.82322874 4.85104019 4.60577037
#  8.11653639 8.55373399] [87793.875] [[0.33229904 0.66770096]]
# [87793.875] [8.76254164 2.40324077 8.77518014 3.82322874 4.85104019 4.60577037
#  8.11653639 8.55373399] [[0.33229904 0.66770096]]
#
# No more feasible directions at iteration 1829 . [29705.375]
# [4.0997709  4.72308756 6.04574065 4.31566137 4.58856511 5.25662271
#  7.65743655 6.56904682] [57087.375] [[0.67658371 0.32341629]]
# [86792.75] [3.91713343 2.50027837 6.61141883 4.27061222 4.5993655  4.98507055
#  7.70735761 6.50905373] [[0.39067028 0.60932972]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.26868462 5.67271368 9.03633636 2.63628808 9.05678772 5.00173664
#  2.85754855 8.3474022 ] [56207.875] [[0.1771564 0.8228436]]
# [56207.875] [2.26868462 5.67271368 9.03633636 2.63628808 9.05678772 5.00173664
#  2.85754855 8.3474022 ] [[0.1771564 0.8228436]]
#
# [5.51311011 6.26822205 3.42095021 9.23743387 7.05662242 6.82980833
#  8.57853598 3.86830712] [35101.] [[0.59698081 0.40301919]]
# [35101.] [5.51311011 6.26822205 3.42095021 9.23743387 7.05662242 6.82980833
#  8.57853598 3.86830712] [[0.59698081 0.40301919]]
#
# No more feasible directions at iteration 9915 . [45874.125]
# [3.73422297 7.87510607 2.50984863 7.37213942 8.75389144 7.97735359
#  7.53928296 8.55897645] [27684.] [[0.12932459 0.87067541]]
# [73558.125] [3.54116544 2.50085729 5.18229755 6.79937672 8.77874314 8.24430474
#  7.6878146  8.17885511] [[0.00253534 0.99746466]]
#
# No more feasible directions at iteration 0 . [0.]
# [7.53381978 5.0247256  4.36767679 2.42057232 8.78170563 6.50598406
#  6.48295633 9.8428026 ] [45592.75] [[0.06602027 0.93397973]]
# [45592.75] [7.53381978 5.0247256  4.36767679 2.42057232 8.78170563 6.50598406
#  6.48295633 9.8428026 ] [[0.06602027 0.93397973]]
#
# No more feasible directions at iteration 693 . [9114.]
# [6.27364679 3.25691991 5.53904012 4.37568764 6.32528265 7.43092455
#  3.56693159 9.59640105] [63719.375] [[0.00910826 0.99089174]]
# [72833.375] [6.19913168 2.50049247 5.72320569 4.35988516 6.29883389 7.30366416
#  3.60164858 9.57198905] [[0.00645927 0.99354073]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.76717208 2.22148718 5.49317226 6.27369954 8.27637759 9.23078108
#  2.38469621 9.09560579] [72786.375] [[2.38231150e-04 9.99761769e-01]]
# [72786.375] [2.76717208 2.22148718 5.49317226 6.27369954 8.27637759 9.23078108
#  2.38469621 9.09560579] [[2.38231150e-04 9.99761769e-01]]
#
# No more feasible directions at iteration 107 . [1710.875]
# [7.80140724 2.62842748 5.54328779 9.13336153 7.01419669 5.73058897
#  4.2462284  6.93044481] [71372.25] [[0.08863983 0.91136017]]
# [73083.125] [7.79192024 2.50027465 5.57683093 9.12584258 7.01231531 5.70711578
#  4.25236638 6.92645496] [[0.08410689 0.91589311]]
#
# No more feasible directions at iteration 3442 . [27441.]
# [9.69966537 5.41007866 9.69943169 7.06700543 5.13563692 8.98541662
#  5.00715795 6.94953862] [48743.25] [[0.01486025 0.98513975]]
# [76184.25] [9.35668088 2.50023248 9.92852095 7.02928048 4.964241   8.35883397
#  5.1802129  6.88907893] [[0.00506523 0.99493477]]
#
# No more feasible directions at iteration 1997 . [19063.125]
# [8.56216044 4.33776831 7.93039701 4.37255955 9.41797969 8.24600758
#  2.72828151 6.3260847 ] [53922.] [[0.00432167 0.99567833]]
# [72985.125] [8.33101035 2.50009511 8.17958579 4.38879019 9.31274506 7.76136116
#  2.86128384 6.2956871 ] [[0.0023939 0.9976061]]
#
# No more feasible directions at iteration 0 . [0.]
# [6.70066522 3.04066453 3.44555526 2.19836695 3.57994109 6.26423593
#  4.54553226 7.60479519] [62393.] [[0.17271198 0.82728802]]
# [62393.] [6.70066522 3.04066453 3.44555526 2.19836695 3.57994109 6.26423593
#  4.54553226 7.60479519] [[0.17271198 0.82728802]]
#
# No more feasible directions at iteration 0 . [0.]
# [6.91978916 4.53707388 7.9328357  8.30605018 9.08887307 6.69618702
#  2.00585872 2.81610416] [56248.] [[0.07341165 0.92658835]]
# [56248.] [6.91978916 4.53707388 7.9328357  8.30605018 9.08887307 6.69618702
#  2.00585872 2.81610416] [[0.07341165 0.92658835]]
#
# No more feasible directions at iteration 1610 . [17577.25]
# [7.83616152 4.12446818 8.26146515 7.8197602  2.56544452 9.52279921
#  6.45425932 4.03578958] [59301.25] [[0.02404717 0.97595283]]
# [76878.5] [7.66943792 2.50112132 8.50079935 7.76948966 2.50064488 9.26247291
#  6.56056364 4.03408477] [[0.01156901 0.98843099]]
# No more feasible directions at iteration 4176 . [33443.625]
# [3.03349873 5.98991279 7.60201447 2.65350567 6.81253481 9.09042745
#  2.53521989 7.94049156] [47183.375] [[0.00537574 0.99462426]]
# [80627.] [2.58751113 2.50036976 8.21152371 2.64911089 6.60990868 8.45690626
#  2.71406409 7.88430465] [[0.00120486 0.99879514]]
#
# [2.60843046 3.34646482 5.20140329 9.16694417 6.19210809 3.8501873
#  7.96071749 8.58640565] [69371.625] [[0.6483941 0.3516059]]
# [69371.625] [2.60843046 3.34646482 5.20140329 9.16694417 6.19210809 3.8501873
#  7.96071749 8.58640565] [[0.6483941 0.3516059]]
#
# No more feasible directions at iteration 1639 . [20820.125]
# [3.071609   4.24563298 5.1245792  7.19735674 6.06970858 7.5685513
#  4.64635842 9.32825589] [54772.125] [[0.0190335 0.9809665]]
# [75592.25] [2.93512764 2.50042656 5.61908671 7.08058112 6.02669841 7.34566305
#  4.71663821 9.25985778] [[0.00785209 0.99214791]]
#
# No more feasible directions at iteration 2429 . [20719.875]
# [7.39791924 4.56907301 3.3302831  8.08162675 7.59573274 8.25658487
#  4.14058781 8.33017689] [43732.875] [[0.01186502 0.98813498]]
# [64452.75] [7.25605822 2.50009965 4.06079643 7.93291626 7.53828196 8.00542131
#  4.26200637 8.25236718] [[0.0040207 0.9959793]]
#
# No more feasible directions at iteration 426 . [9712.625]
# [3.84330328 3.11903088 8.63367165 8.88974916 8.81972552 3.69938965
#  8.75334237 8.74292895] [83665.375] [[0.36910819 0.63089181]]
# [93378.] [3.79566142 2.50137924 8.74968513 8.85632016 8.81621157 3.58211697
#  8.77061757 8.71038901] [[0.30957528 0.69042472]]
#
# No more feasible directions at iteration 1 . [0.125]
# [9.37117828 8.91561452 9.63227616 3.66125118 9.98231288 9.72152193
#  9.9229497  7.03697657] [37191.625] [[0.0246534 0.9753466]]
# [37191.75] [9.37116022 8.91563603 9.6322052  3.6613023  9.98230224 9.72158328
#  9.9229387  7.03695784] [[0.02465235 0.97534765]]
#
# No more feasible directions at iteration 5 . [2.]
# [6.31474184 7.9625008  9.62109694 5.82377057 6.71586524 9.89056473
#  6.83650778 5.31607151] [40119.625] [[0.02751705 0.97248295]]
# [40121.625] [6.31459111 7.96158117 9.62105224 5.82379948 6.71577659 9.89067857
#  6.83653127 5.31606841] [[0.02749828 0.97250172]]
#
# No more feasible directions at iteration 1145 . [16330.75]
# [9.98909637 3.78430854 3.97169146 6.37462202 6.25493522 4.41458679
#  5.26680229 8.00511753] [55526.] [[0.59765042 0.40234958]]
# [71856.75] [9.90216462 2.50004444 4.38011594 6.33720151 6.26376849 4.23140993
#  5.30197265 7.95874647] [[0.4346544 0.5653456]]
#
# No more feasible directions at iteration 1515 . [17863.5]
# [7.74386775 4.06369632 7.97899711 9.64484403 8.47690503 7.27085673
#  4.46140229 6.17626983] [58919.75] [[0.02170348 0.97829652]]
# [76783.25] [7.60391099 2.50041824 8.24934763 9.55401569 8.42100184 6.91521972
#  4.55749576 6.12820285] [[0.01219307 0.98780693]]
#
# No more feasible directions at iteration 0 . [0.]
# [7.95462855 5.20594564 2.04653061 7.76957186 8.74530383 7.54793829
#  5.16137886 7.01085736] [36650.5] [[0.05609347 0.94390653]]
# [36650.5] [7.95462855 5.20594564 2.04653061 7.76957186 8.74530383 7.54793829
#  5.16137886 7.01085736] [[0.05609347 0.94390653]]
#
# No more feasible directions at iteration 0 . [0.]
# [5.47555738 4.89731791 5.30721761 2.42642505 5.30376549 8.10282177
#  9.92544991 8.50215086] [50802.625] [[0.05589446 0.94410554]]
# [50802.625] [5.47555738 4.89731791 5.30721761 2.42642505 5.30376549 8.10282177
#  9.92544991 8.50215086] [[0.05589446 0.94410554]]
#
# [2.60843046 3.34646482 5.20140329 9.16694417 6.19210809 3.8501873
#  7.96071749 8.58640565] [69371.625] [[0.6483941 0.3516059]]
# [69371.625] [2.60843046 3.34646482 5.20140329 9.16694417 6.19210809 3.8501873
#  7.96071749 8.58640565] [[0.6483941 0.3516059]]
#
# No more feasible directions at iteration 4291 . [38561.]
# [7.90470929 6.3330749  8.19267455 4.62380641 8.59141207 7.24683375
#  9.46541789 6.35831765] [45171.625] [[0.1567709 0.8432291]]
# [83732.625] [7.50895865 2.50112697 8.75343834 4.65999531 8.52495229 6.60172344
#  9.61970771 6.20797556] [[0.03215401 0.96784599]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.23961504 8.3725092  5.76464559 8.49609801 5.52093922 8.51519405
#  6.79952069 5.19043906] [34143.625] [[0.2958653 0.7041347]]
# [34143.625] [2.23961504 8.3725092  5.76464559 8.49609801 5.52093922 8.51519405
#  6.79952069 5.19043906] [[0.2958653 0.7041347]]
#
# [3.25988679 4.16643163 6.11047137 9.05088628 3.3246417  7.48755927
#  9.4141829  8.73158176] [58798.875] [[0.10074199 0.89925801]]
# [73167.5] [3.18311918 3.00990802 6.41033081 8.96306899 3.31423652 7.39447829
#  9.44826518 8.68052097] [[0.05463034 0.94536966]]
#
# No more feasible directions at iteration 247 . [4177.875]
# [5.05090265 2.80766466 7.25096646 4.20299825 7.8717653  6.32971129
#  3.56360566 6.14832627] [77159.25] [[0.02879296 0.97120704]]
# [81337.125] [5.01876048 2.50120888 7.31002905 4.19906895 7.86314669 6.26374395
#  3.57933993 6.14248614] [[0.02555779 0.97444221]]
#
# No more feasible directions at iteration 0 . [0.]
# [7.63168609 5.96373284 2.15863472 3.58381163 6.85386144 7.45234988
#  8.66903784 3.46879002] [34612.125] [[0.45862215 0.54137785]]
# [34612.125] [7.63168609 5.96373284 2.15863472 3.58381163 6.85386144 7.45234988
#  8.66903784 3.46879002] [[0.45862215 0.54137785]]
#
# No more feasible directions at iteration 0 . [0.]
# [8.70381094 2.18843833 9.1430904  2.63586435 9.087634   8.09430626
#  6.82660793 3.75412987] [79882.] [[0.00457791 0.99542209]]
# [79882.] [8.70381094 2.18843833 9.1430904  2.63586435 9.087634   8.09430626
#  6.82660793 3.75412987] [[0.00457791 0.99542209]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.18813213 2.9292535  9.03466641 7.78791587 3.77742236 6.61714789
#  2.36987329 4.4287817 ] [82082.375] [[0.07621508 0.92378492]]
# [82082.375] [2.18813213 2.9292535  9.03466641 7.78791587 3.77742236 6.61714789
#  2.36987329 4.4287817 ] [[0.07621508 0.92378492]]
#
# No more feasible directions at iteration 2542 . [33192.]
# [4.44841722 5.20342389 5.16202903 8.58487838 8.12519792 5.01099894
#  4.010348   4.34023045] [48604.75] [[0.59891146 0.40108854]]
# [81796.75] [4.27432043 2.50051715 5.99130804 8.40252972 8.14415535 4.56537502
#  4.11401676 4.28102183] [[0.2858673 0.7141327]]
#
# No more feasible directions at iteration 1760 . [24790.875]
# [7.55770164 4.50361243 8.21981413 9.34081355 7.3479328  6.0781645
#  8.63311071 5.71729505] [59825.625] [[0.27200781 0.72799219]]
# [84616.5] [7.3980725  2.50051318 8.57570557 9.24464382 7.32662376 5.71420779
#  8.71847701 5.642745  ] [[0.13413696 0.86586304]]
#
# No more feasible directions at iteration 1036 . [14914.5]
# [6.7654802  3.66965415 2.85853634 3.91202373 9.98809675 6.17321435
#  9.28874301 5.78085487] [56080.125] [[0.14166532 0.85833468]]
# [70994.625] [6.6750139  2.50085549 3.23173049 3.89844626 9.99429681 6.02664176
#  9.34348515 5.74086299] [[0.08151386 0.91848614]]
#
# No more feasible directions at iteration 0 . [0.]
# [6.08523087 2.4149837  5.01563924 3.35185074 9.76801024 7.05517285
#  6.78332714 7.67508825] [74143.] [[0.00788028 0.99211972]]
# [74143.] [6.08523087 2.4149837  5.01563924 3.35185074 9.76801024 7.05517285
#  6.78332714 7.67508825] [[0.00788028 0.99211972]]
#
# No more feasible directions at iteration 153 . [2069.375]
# [9.49851485 2.66765712 2.51020965 4.38218088 4.97826409 7.07132962
#  5.61656206 6.3882133 ] [59993.] [[0.0786074 0.9213926]]
# [62062.375] [9.485129   2.50078083 2.56668972 4.38025976 4.97708476 7.05237605
#  5.62486102 6.38557334] [[0.07223202 0.92776798]]
#
# No more feasible directions at iteration 3442 . [27441.]
# [9.69966537 5.41007866 9.69943169 7.06700543 5.13563692 8.98541662
#  5.00715795 6.94953862] [48743.25] [[0.01486025 0.98513975]]
# [76184.25] [9.35668088 2.50023248 9.92852095 7.02928048 4.964241   8.35883397
#  5.1802129  6.88907893] [[0.00506523 0.99493477]]
#
# No more feasible directions at iteration 36 . [17.875]
# [3.55884111 8.82054754 5.0221135  9.09558674 9.55597083 9.22706312
#  3.25523373 5.21691621] [34522.125] [[0.04113455 0.95886545]]
# [34540.] [3.56019109 8.82253334 5.02785423 9.09328862 9.5563612  9.23133187
#  3.25498786 5.21690397] [[0.04094845 0.95905155]]
#
# No more feasible directions at iteration 1481 . [19421.875]
# [4.27708762 4.11694671 5.97936026 7.57877923 5.32415722 7.90499279
#  6.21599661 5.62194636] [58710.75] [[0.04776399 0.95223601]]
# [78132.625] [4.14332216 2.50011956 6.37707861 7.49147316 5.29248017 7.68245918
#  6.29850273 5.58920332] [[0.02178918 0.97821082]]
# No more feasible directions at iteration 768 . [8237.375]
# [9.22545751 3.26607377 8.6440655  9.16676316 4.04581057 9.74295102
#  4.85377851 8.01883358] [63247.875] [[0.00181311 0.99818689]]
# [71485.25] [9.14491063 2.50048979 8.73778704 9.13014529 3.99701522 9.59101834
#  4.90659439 7.9992584 ] [[0.00134077 0.99865923]]
#
# No more feasible directions at iteration 5967 . [42296.25]
# [5.71548708 7.10260945 8.71101024 8.82660091 8.47732381 7.75343561
#  6.88407201 6.98627806] [41477.875] [[0.07955794 0.92044206]]
# [83774.125] [5.31972671 2.50087625 9.42643085 8.53055844 8.34281512 6.9512251
#  7.07878708 6.76779235] [[0.01143352 0.98856648]]
#
# [2.75783751 5.7397775  9.11131928 8.01095659 2.98231941 7.33500087
#  9.95023045 9.04886334] [51908.125] [[0.2129533 0.7870467]]
# [87443.] [ 2.51149826  2.73799765  9.61392318  7.8386911   2.93508022  7.0218149
#  10.0093047   8.90867265] [[0.05214849 0.94785151]]
#
# No more feasible directions at iteration 2 . [0.625]
# [6.08199065 8.40358411 5.89640539 4.42759739 7.53155837 9.71729336
#  3.73004212 6.38113378] [37853.625] [[0.02548199 0.97451801]]
# [37854.25] [6.08199342 8.40359255 5.89660689 4.42760808 7.5315512  9.71749277
#  3.73002654 6.38114595] [[0.02547543 0.97452457]]
#
# Non greedy step
# Non greedy step
# Non greedy step
# Non greedy step
# Non greedy step
# Non greedy step
# No more feasible directions at iteration 6 . [114.625]
# [8.80520968 2.50792814 8.8845873  9.7151944  9.88507815 3.43088659
#  2.56398478 7.8957911 ] [84950.375] [[0.18172691 0.81827309]]
# [85065.] [8.80453914 2.50006519 8.88594417 9.71480747 9.88491451 3.4287996
#  2.5643135  7.89546474] [[0.18133645 0.81866355]]
#
# No more feasible directions at iteration 1430 . [16137.125]
# [3.29835214 3.93847072 5.76595876 8.42154026 8.73202246 8.79435178
#  4.57508597 9.83259606] [55803.875] [[0.00123864 0.99876136]]
# [71941.] [3.17611674 2.50093018 6.11905223 8.30586744 8.66491479 8.55705841
#  4.66013313 9.76243752] [[6.47486007e-04 9.99352514e-01]]
#
# No more feasible directions at iteration 5381 . [33203.875]
# [8.90764272 6.41704043 7.22060632 9.09946315 6.14413484 8.69161938
#  7.7616512  9.18678414] [41375.625] [[0.03327852 0.96672148]]
# [74579.5] [8.59966621 2.50061544 7.98789329 8.84911559 5.99463736 8.24481177
#  7.93009333 8.95767637] [[0.00467726 0.99532274]]
#
# No more feasible directions at iteration 18 . [11.]
# [6.39951632 9.79564212 7.35208721 9.51407639 6.46764197 8.22852305
#  8.03919005 9.79319301] [34911.5] [[0.27523274 0.72476726]]
# [34922.5] [6.40040471 9.7975372  7.35358993 9.51315212 6.46805614 8.23179453
#  8.0382959  9.79253688] [[0.27464148 0.72535852]]
#
# No more feasible directions at iteration 1304 . [18456.875]
# [9.25067508 3.96535082 6.35253056 7.82715472 7.14608988 4.61303537
#  3.0952779  3.68570653] [61238.25] [[0.61674265 0.38325735]]
# [79695.125] [9.13402117 2.50052734 6.71489202 7.77856276 7.14284831 4.30349954
#  3.161474   3.66797236] [[0.46437965 0.53562035]]
#
# No more feasible directions at iteration 1829 . [29705.375]
# [4.0997709  4.72308756 6.04574065 4.31566137 4.58856511 5.25662271
#  7.65743655 6.56904682] [57087.375] [[0.67658371 0.32341629]]
# [86792.75] [3.91713343 2.50027837 6.61141883 4.27061222 4.5993655  4.98507055
#  7.70735761 6.50905373] [[0.39067028 0.60932972]]
#
# No more feasible directions at iteration 0 . [0.]
# [9.7911429  2.02615873 4.52231431 3.79395457 6.29207474 8.47450088
#  6.39128321 2.82500429] [71616.25] [[0.01522675 0.98477325]]
# [71616.25] [9.7911429  2.02615873 4.52231431 3.79395457 6.29207474 8.47450088
#  6.39128321 2.82500429] [[0.01522675 0.98477325]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.24938549 7.1355691  9.60357587 6.03064032 9.55679646 9.94656893
#  5.29311738 3.4859656 ] [43081.75] [[0.00652788 0.99347212]]
# [43081.75] [2.24938549 7.1355691  9.60357587 6.03064032 9.55679646 9.94656893
#  5.29311738 3.4859656 ] [[0.00652788 0.99347212]]
#
# No more feasible directions at iteration 4098 . [38739.625]
# [4.20404871 6.23903807 9.53722911 4.87370122 5.62376644 8.01605349
#  3.50606934 3.87734483] [48286.125] [[0.09044017 0.90955983]]
# [87025.75] [ 3.76101988  2.50007473 10.00294697  4.83948362  5.48689344  7.23707995
#   3.69582191  3.88751466] [[0.02157849 0.97842151]]
#
# [8.80520968 2.50792814 8.8845873  9.7151944  9.88507815 3.43088659
#  2.56398478 7.8957911 ] [84950.375] [[0.18172691 0.81827309]]
# [84950.375] [8.80520968 2.50792814 8.8845873  9.7151944  9.88507815 3.43088659
#  2.56398478 7.8957911 ] [[0.18172691 0.81827309]]
#
# [3.15625135 5.03102599 4.70969599 3.06083945 9.29774736 4.79142794
#  8.05243392 4.79614511] [52802.25] [[0.65031248 0.34968752]]
# [52802.25] [3.15625135 5.03102599 4.70969599 3.06083945 9.29774736 4.79142794
#  8.05243392 4.79614511] [[0.65031248 0.34968752]]
#
# No more feasible directions at iteration 2620 . [26817.375]
# [7.97029877 4.9929493  4.98303034 7.82559806 4.23966158 7.0562222
#  5.97291621 8.46008862] [46405.625] [[0.17469105 0.82530895]]
# [73223.] [7.79812953 2.50118277 5.71998676 7.69139817 4.21270434 6.80115235
#  6.0541824  8.36940905] [[0.05079543 0.94920457]]
#
# No more feasible directions at iteration 5907 . [44795.5]
# [3.07421164 7.20075127 6.37380909 4.27023187 5.28944986 7.86059427
#  6.30914519 7.51564167] [39819.75] [[0.17285526 0.82714474]]
# [84615.25] [2.63884252 2.50018822 7.57694201 4.15281474 5.21459901 7.48489185
#  6.42165652 7.38295921] [[0.01374018 0.98625982]]
#
# No more feasible directions at iteration 0 . [0.]
# [7.73649831 6.41277343 6.98165062 9.38499875 7.25833299 9.01180244
#  2.22250342 2.63210608] [40571.] [[0.03774953 0.96225047]]
# [40571.] [7.73649831 6.41277343 6.98165062 9.38499875 7.25833299 9.01180244
#  2.22250342 2.63210608] [[0.03774953 0.96225047]]
#
# No more feasible directions at iteration 3153 . [23041.375]
# [7.59534288 4.98718601 2.62978363 5.69085127 8.31056625 9.62661298
#  9.06865306 9.8931685 ] [40967.875] [[0.00368014 0.99631986]]
# [64009.25] [7.40762726 2.50071115 3.50509377 5.5938883  8.23505919 9.50663759
#  9.2150247  9.74438475] [[8.14713828e-04 9.99185286e-01]]
#
# No more feasible directions at iteration 0 . [0.]
# [3.42529972 3.12091281 6.22450424 3.86772238 2.05499433 5.28858019
#  7.22884385 3.77197677] [77379.75] [[0.75310381 0.24689619]]
# [77379.75] [3.42529972 3.12091281 6.22450424 3.86772238 2.05499433 5.28858019
#  7.22884385 3.77197677] [[0.75310381 0.24689619]]
#
# No more feasible directions at iteration 1998 . [23525.875]
# [4.73444547 4.55713543 4.76768044 3.43126218 6.18119505 7.97143628
#  6.97046524 6.40215195] [52617.] [[0.04633888 0.95366112]]
# [76142.875] [4.54083728 2.5012385  5.32311635 3.40953348 6.14743079 7.73308523
#  7.06609006 6.35980687] [[0.01598226 0.98401774]]
#
# No more feasible directions at iteration 3442 . [27441.]
# [9.69966537 5.41007866 9.69943169 7.06700543 5.13563692 8.98541662
#  5.00715795 6.94953862] [48743.25] [[0.01486025 0.98513975]]
# [76184.25] [9.35668088 2.50023248 9.92852095 7.02928048 4.964241   8.35883397
#  5.1802129  6.88907893] [[0.00506523 0.99493477]]
#
# No more feasible directions at iteration 33 . [568.75]
# [7.80505753 2.54229604 8.5460933  4.07310714 7.07032581 7.27334893
#  7.69894332 2.86202971] [80545.375] [[0.04424845 0.95575155]]
# [81114.125] [7.80033917 2.50064799 8.55159448 4.07357005 7.06920671 7.26435554
#  7.70153779 2.8616896 ] [[0.04356207 0.95643793]]
#
# No more feasible directions at iteration 1835 . [24541.75]
# [4.00903864 4.51987833 7.80549751 8.69561418 8.49851633 6.60813089
#  4.9609437  8.97707959] [58127.375] [[0.02771196 0.97228804]]
# [82669.125] [3.83856451 2.50119598 8.2040179  8.56086212 8.43979418 6.21614146
#  5.04477485 8.88088981] [[0.01208717 0.98791283]]
#
# No more feasible directions at iteration 0 . [0.]
# [6.91978916 4.53707388 7.9328357  8.30605018 9.08887307 6.69618702
#  2.00585872 2.81610416] [56248.] [[0.07341165 0.92658835]]
# [56248.] [6.91978916 4.53707388 7.9328357  8.30605018 9.08887307 6.69618702
#  2.00585872 2.81610416] [[0.07341165 0.92658835]]
#
# No more feasible directions at iteration 0 . [0.]
# [6.25437912 4.24696162 3.97600304 7.53631715 2.00278013 7.8963462
#  2.3164338  8.83421963] [49163.125] [[0.05026804 0.94973196]]
# [49163.125] [6.25437912 4.24696162 3.97600304 7.53631715 2.00278013 7.8963462
#  2.3164338  8.83421963] [[0.05026804 0.94973196]]
#
# No more feasible directions at iteration 0 . [0.]
# [7.04238323 4.81812905 2.19057057 3.73409517 8.33735545 5.51629649
#  2.58606507 4.98470942] [41571.75] [[0.38525431 0.61474569]]
# [41571.75] [7.04238323 4.81812905 2.19057057 3.73409517 8.33735545 5.51629649
#  2.58606507 4.98470942] [[0.38525431 0.61474569]]
# Non greedy step
# [4.20966833 4.82755058 8.33112372 6.05386772 6.45425962 7.42645223
#  9.66165679 9.32013025] [57937.] [[0.04242566 0.95757434]]
# [80969.75] [4.02767582 2.87234451 8.65391752 5.99019685 6.40756566 7.15124992
#  9.72474386 9.22114327] [[0.01700131 0.98299869]]
#
# Non greedy step
# [3.15625135 5.03102599 4.70969599 3.06083945 9.29774736 4.79142794
#  8.05243392 4.79614511] [52802.25] [[0.65031248 0.34968752]]
# [52812.125] [3.15618255 5.0300745  4.71002007 3.06082923 9.29777457 4.79133385
#  8.05245251 4.7961173 ] [[0.6501873 0.3498127]]
#
# No more feasible directions at iteration 0 . [0.]
# [8.40079326 9.3841775  2.31882667 5.22013186 6.65516209 8.69986095
#  6.19268974 9.05128145] [31204.375] [[0.22412324 0.77587676]]
# [31204.375] [8.40079326 9.3841775  2.31882667 5.22013186 6.65516209 8.69986095
#  6.19268974 9.05128145] [[0.22412324 0.77587676]]
#
# No more feasible directions at iteration 1036 . [14914.5]
# [6.7654802  3.66965415 2.85853634 3.91202373 9.98809675 6.17321435
#  9.28874301 5.78085487] [56080.125] [[0.14166532 0.85833468]]
# [70994.625] [6.6750139  2.50085549 3.23173049 3.89844626 9.99429681 6.02664176
#  9.34348515 5.74086299] [[0.08151386 0.91848614]]
#
# No more feasible directions at iteration 2830 . [31556.5]
# [7.73957652 5.27381196 4.09706971 7.71272833 8.64466748 5.33383564
#  7.07827247 8.3562118 ] [43181.125] [[0.39341197 0.60658803]]
# [74737.625] [7.5766708  2.50028612 5.00674236 7.56334539 8.66513695 4.98781964
#  7.15702799 8.20984404] [[0.1294687 0.8705313]]
#
# No more feasible directions at iteration 276 . [3352.375]
# [6.27808473 2.7833712  2.74428348 8.30851092 7.19099635 8.49697235
#  3.67889578 3.3505978 ] [57495.] [[0.01170548 0.98829452]]
# [60847.375] [6.25748488 2.50073878 2.84260574 8.28986996 7.18540258 8.45625951
#  3.7010826  3.34988134] [[0.01015567 0.98984433]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.27568762 5.53307114 2.17336102 5.82804661 9.9896783  9.04718562
#  9.71145997 9.88106918] [37632.75] [[0.00564042 0.99435958]]
# [37632.75] [2.27568762 5.53307114 2.17336102 5.82804661 9.9896783  9.04718562
#  9.71145997 9.88106918] [[0.00564042 0.99435958]]
#
# No more feasible directions at iteration 1998 . [23525.875]
# [4.73444547 4.55713543 4.76768044 3.43126218 6.18119505 7.97143628
#  6.97046524 6.40215195] [52617.] [[0.04633888 0.95366112]]
# [76142.875] [4.54083728 2.5012385  5.32311635 3.40953348 6.14743079 7.73308523
#  7.06609006 6.35980687] [[0.01598226 0.98401774]]
#
# No more feasible directions at iteration 1481 . [19421.875]
# [4.27708762 4.11694671 5.97936026 7.57877923 5.32415722 7.90499279
#  6.21599661 5.62194636] [58710.75] [[0.04776399 0.95223601]]
# [78132.625] [4.14332216 2.50011956 6.37707861 7.49147316 5.29248017 7.68245918
#  6.29850273 5.58920332] [[0.02178918 0.97821082]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.77580922 3.72582298 2.45069058 8.23582683 9.28100114 6.83650414
#  4.17394074 6.97840703] [50780.125] [[0.02834051 0.97165949]]
# [50780.125] [2.77580922 3.72582298 2.45069058 8.23582683 9.28100114 6.83650414
#  4.17394074 6.97840703] [[0.02834051 0.97165949]]
#
# No more feasible directions at iteration 0 . [0.]
# [9.11734161 4.62170205 7.94388518 6.60341554 2.49021443 6.55352558
#  9.78509528 8.66810885] [56736.] [[0.39365471 0.60634529]]
# [56736.] [9.11734161 4.62170205 7.94388518 6.60341554 2.49021443 6.55352558
#  9.78509528 8.66810885] [[0.39365471 0.60634529]]
#
# No more feasible directions at iteration 59 . [31.875]
# [5.49215417 8.26276766 6.21403859 8.44036831 9.6772564  6.78353181
#  2.86848029 5.2141351 ] [35755.875] [[0.31939203 0.68060797]]
# [35787.75] [5.49307842 8.25393922 6.22364263 8.43759055 9.6783605  6.78560358
#  2.86783763 5.21368762] [[0.31725705 0.68274295]]
#
# No more feasible directions at iteration 0 . [0.]
# [9.11734161 4.62170205 7.94388518 6.60341554 2.49021443 6.55352558
#  9.78509528 8.66810885] [56736.] [[0.39365471 0.60634529]]
# [56736.] [9.11734161 4.62170205 7.94388518 6.60341554 2.49021443 6.55352558
#  9.78509528 8.66810885] [[0.39365471 0.60634529]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.41785327 8.26680725 4.55367652 4.91451848 5.77937036 9.39042502
#  2.42309088 4.50039664] [35139.375] [[0.07974718 0.92025282]]
# [35139.375] [2.41785327 8.26680725 4.55367652 4.91451848 5.77937036 9.39042502
#  2.42309088 4.50039664] [[0.07974718 0.92025282]]
#
# No more feasible directions at iteration 0 . [0.]
# [6.70066522 3.04066453 3.44555526 2.19836695 3.57994109 6.26423593
#  4.54553226 7.60479519] [62393.] [[0.17271198 0.82728802]]
# [62393.] [6.70066522 3.04066453 3.44555526 2.19836695 3.57994109 6.26423593
#  4.54553226 7.60479519] [[0.17271198 0.82728802]]
#
# No more feasible directions at iteration 1997 . [19063.125]
# [8.56216044 4.33776831 7.93039701 4.37255955 9.41797969 8.24600758
#  2.72828151 6.3260847 ] [53922.] [[0.00432167 0.99567833]]
# [72985.125] [8.33101035 2.50009511 8.17958579 4.38879019 9.31274506 7.76136116
#  2.86128384 6.2956871 ] [[0.0023939 0.9976061]]
#
# No more feasible directions at iteration 0 . [0.]
# [9.46572723 8.31048572 9.53400387 8.08596509 8.53904379 8.14953446
#  2.57197839 2.32150929] [38359.5] [[0.17856321 0.82143679]]
# [38359.5] [9.46572723 8.31048572 9.53400387 8.08596509 8.53904379 8.14953446
#  2.57197839 2.32150929] [[0.17856321 0.82143679]]
#
# No more feasible directions at iteration 351 . [200.5]
# [9.09445845 7.44103934 4.08270257 5.52141517 8.45846964 9.00860641
#  6.31020385 6.91349473] [35338.] [[0.04440207 0.95559793]]
# [35538.5] [9.09602563 7.39264381 4.14327577 5.52064915 8.46090375 9.04003972
#  6.31050215 6.90949568] [[0.04125168 0.95874832]]
#
# Non greedy step
# [8.80520968 2.50792814 8.8845873  9.7151944  9.88507815 3.43088659
#  2.56398478 7.8957911 ] [84950.375] [[0.18172691 0.81827309]]
# [84969.375] [8.805098   2.5066183  8.88481339 9.71512992 9.88505091 3.43053895
#  2.56403952 7.89573672] [[0.18166182 0.81833818]]
#
# No more feasible directions at iteration 5303 . [44180.25]
# [3.66606175 6.9471738  5.86707696 7.66763302 6.5814646  7.81747032
#  9.11547434 4.66208075] [39312.25] [[0.31995839 0.68004161]]
# [83492.5] [3.35884264 2.50002564 7.08658517 7.39511079 6.58927992 7.48264118
#  9.29167527 4.53947903] [[0.0334306 0.9665694]]
#
# No more feasible directions at iteration 18 . [11.]
# [6.39951632 9.79564212 7.35208721 9.51407639 6.46764197 8.22852305
#  8.03919005 9.79319301] [34911.5] [[0.27523274 0.72476726]]
# [34922.5] [6.40040471 9.7975372  7.35358993 9.51315212 6.46805614 8.23179453
#  8.0382959  9.79253688] [[0.27464148 0.72535852]]
#
# No more feasible directions at iteration 36 . [17.875]
# [3.55884111 8.82054754 5.0221135  9.09558674 9.55597083 9.22706312
#  3.25523373 5.21691621] [34522.125] [[0.04113455 0.95886545]]
# [34540.] [3.56019109 8.82253334 5.02785423 9.09328862 9.5563612  9.23133187
#  3.25498786 5.21690397] [[0.04094845 0.95905155]]
#
# No more feasible directions at iteration 0 . [0.]
# [8.44049955 2.1746643  5.92928775 4.05607782 8.02181382 7.98377955
#  9.71931208 2.91415316] [78591.125] [[0.02200222 0.97799778]]
# [78591.125] [8.44049955 2.1746643  5.92928775 4.05607782 8.02181382 7.98377955
#  9.71931208 2.91415316] [[0.02200222 0.97799778]]
#
# No more feasible directions at iteration 53 . [764.125]
# [5.77545084 2.56032368 2.84687668 5.7254832  8.17997311 7.81889402
#  6.69193553 5.6801515 ] [64741.] [[0.01323533 0.98676467]]
# [65505.125] [5.7707049  2.50052124 2.86604694 5.72323862 8.17912793 7.81106663
#  6.69564954 5.67876571] [[0.01283602 0.98716398]]
#
# No more feasible directions at iteration 0 . [0.]
# [3.57861903 6.280178   8.65911151 9.68024777 5.08156352 7.32347276
#  7.9498362  2.06146579] [47244.75] [[0.51559416 0.48440584]]
# [47244.75] [3.57861903 6.280178   8.65911151 9.68024777 5.08156352 7.32347276
#  7.9498362  2.06146579] [[0.51559416 0.48440584]]
#
# No more feasible directions at iteration 0 . [0.]
# [7.53381978 5.0247256  4.36767679 2.42057232 8.78170563 6.50598406
#  6.48295633 9.8428026 ] [45592.75] [[0.06602027 0.93397973]]
# [45592.75] [7.53381978 5.0247256  4.36767679 2.42057232 8.78170563 6.50598406
#  6.48295633 9.8428026 ] [[0.06602027 0.93397973]]
#
# No more feasible directions at iteration 1191 . [17686.875]
# [3.47162806 3.8712053  4.81450869 7.01926862 4.67299764 6.82779323
#  4.26650141 3.42291838] [59196.875] [[0.22337033 0.77662967]]
# [76883.75] [3.36588849 2.5009554  5.21922399 6.94761477 4.66586175 6.64126121
#  4.33313456 3.41756079] [[0.12365772 0.87634228]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.26868462 5.67271368 9.03633636 2.63628808 9.05678772 5.00173664
#  2.85754855 8.3474022 ] [56207.875] [[0.1771564 0.8228436]]
# [56207.875] [2.26868462 5.67271368 9.03633636 2.63628808 9.05678772 5.00173664
#  2.85754855 8.3474022 ] [[0.1771564 0.8228436]]
#
# No more feasible directions at iteration 0 . [0.]
# [3.45178366 3.16493323 3.21300463 9.45070468 8.7591459  8.33173528
#  2.20600069 6.42737392] [54759.875] [[0.00319767 0.99680233]]
# [54759.875] [3.45178366 3.16493323 3.21300463 9.45070468 8.7591459  8.33173528
#  2.20600069 6.42737392] [[0.00319767 0.99680233]]
#
# No more feasible directions at iteration 0 . [0.]
# [4.17974297 2.25156054 7.04646572 8.54041952 8.84656144 8.72235424
#  8.18360111 6.28557734] [79831.75] [[0.00175626 0.99824374]]
# [79831.75] [4.17974297 2.25156054 7.04646572 8.54041952 8.84656144 8.72235424
#  8.18360111 6.28557734] [[0.00175626 0.99824374]]
#
# No more feasible directions at iteration 1 . [0.125]
# [9.37117828 8.91561452 9.63227616 3.66125118 9.98231288 9.72152193
#  9.9229497  7.03697657] [37191.625] [[0.0246534 0.9753466]]
# [37191.75] [9.37116022 8.91563603 9.6322052  3.6613023  9.98230224 9.72158328
#  9.9229387  7.03695784] [[0.02465235 0.97534765]]
#
# No more feasible directions at iteration 0 . [0.]
# [9.11734161 4.62170205 7.94388518 6.60341554 2.49021443 6.55352558
#  9.78509528 8.66810885] [56736.] [[0.39365471 0.60634529]]
# [56736.] [9.11734161 4.62170205 7.94388518 6.60341554 2.49021443 6.55352558
#  9.78509528 8.66810885] [[0.39365471 0.60634529]]
# No more feasible directions at iteration 1036 . [14914.5]
# [6.7654802  3.66965415 2.85853634 3.91202373 9.98809675 6.17321435
#  9.28874301 5.78085487] [56080.125] [[0.14166532 0.85833468]]
# [70994.625] [6.6750139  2.50085549 3.23173049 3.89844626 9.99429681 6.02664176
#  9.34348515 5.74086299] [[0.08151386 0.91848614]]
#
# No more feasible directions at iteration 53 . [764.125]
# [5.77545084 2.56032368 2.84687668 5.7254832  8.17997311 7.81889402
#  6.69193553 5.6801515 ] [64741.] [[0.01323533 0.98676467]]
# [65505.125] [5.7707049  2.50052124 2.86604694 5.72323862 8.17912793 7.81106663
#  6.69564954 5.67876571] [[0.01283602 0.98716398]]
#
# No more feasible directions at iteration 0 . [0.]
# [6.08523087 2.4149837  5.01563924 3.35185074 9.76801024 7.05517285
#  6.78332714 7.67508825] [74143.] [[0.00788028 0.99211972]]
# [74143.] [6.08523087 2.4149837  5.01563924 3.35185074 9.76801024 7.05517285
#  6.78332714 7.67508825] [[0.00788028 0.99211972]]
#
# No more feasible directions at iteration 2824 . [34906.125]
# [3.21984115 5.39741914 3.06195252 3.71725886 3.17636821 6.49714444
#  4.97751651 3.937595  ] [40994.5] [[0.68760074 0.31239926]]
# [75900.625] [3.00499652 2.50023947 4.12797564 3.64341541 3.21650732 6.30090261
#  5.06562088 3.94274683] [[0.26655091 0.73344909]]
#
# No more feasible directions at iteration 4050 . [34022.]
# [5.109143   5.87968232 2.62457319 4.73146964 4.27903775 8.8700357
#  8.53360342 4.26528994] [37294.75] [[0.18534504 0.81465496]]
# [71316.75] [4.86528313 2.5003003  3.90675496 4.63918092 4.29323988 8.83722636
#  8.69875294 4.24808922] [[0.02198692 0.97801308]]
#
# [3.15625135 5.03102599 4.70969599 3.06083945 9.29774736 4.79142794
#  8.05243392 4.79614511] [52802.25] [[0.65031248 0.34968752]]
# [52802.25] [3.15625135 5.03102599 4.70969599 3.06083945 9.29774736 4.79142794
#  8.05243392 4.79614511] [[0.65031248 0.34968752]]
#
# No more feasible directions at iteration 1890 . [27384.875]
# [6.33425839 4.68945772 8.33101047 5.04150204 3.63316753 6.47734776
#  7.13844727 3.96118992] [59929.125] [[0.49760903 0.50239097]]
# [87314.] [6.11971921 2.50045412 8.71108597 5.02656887 3.61158239 6.12222611
#  7.22130503 3.94124938] [[0.26090729 0.73909271]]
#
# No more feasible directions at iteration 1997 . [19063.125]
# [8.56216044 4.33776831 7.93039701 4.37255955 9.41797969 8.24600758
#  2.72828151 6.3260847 ] [53922.] [[0.00432167 0.99567833]]
# [72985.125] [8.33101035 2.50009511 8.17958579 4.38879019 9.31274506 7.76136116
#  2.86128384 6.2956871 ] [[0.0023939 0.9976061]]
#
# No more feasible directions at iteration 0 . [0.]
# [8.14316892 7.45950784 8.23798354 9.26559455 2.14234778 9.39906092
#  7.67183702 4.93955909] [40069.375] [[0.21972412 0.78027588]]
# [40069.375] [8.14316892 7.45950784 8.23798354 9.26559455 2.14234778 9.39906092
#  7.67183702 4.93955909] [[0.21972412 0.78027588]]
#
# Non greedy step
# [6.36561609 4.46092386 7.76467428 5.86205955 9.90076986 4.4588183
#  6.92587464 5.14131829] [63997.25] [[0.48785716 0.51214284]]
# [64008.875] [6.36552918 4.45989689 7.76489217 5.86204039 9.90077363 4.45861788
#  6.92590707 5.14128295] [[0.48774554 0.51225446]]
#
# No more feasible directions at iteration 7353 . [52892.5]
# [3.35861851 8.00191927 9.67182006 7.29808488 9.83597288 6.28172953
#  2.87220783 4.36908157] [41167.25] [[0.32808573 0.67191427]]
# [94059.75] [ 2.82214693  2.50071451 10.49689969  7.0243941   9.73319005  4.92576709
#   3.06846261  4.25920361] [[0.0624902 0.9375098]]
#
# No more feasible directions at iteration 0 . [0.]
# [8.83000503 3.1276826  3.02323138 9.23555348 2.24817777 7.03314596
#  8.09570781 9.44711057] [55483.25] [[0.15406491 0.84593509]]
# [55483.25] [8.83000503 3.1276826  3.02323138 9.23555348 2.24817777 7.03314596
#  8.09570781 9.44711057] [[0.15406491 0.84593509]]
#
# No more feasible directions at iteration 795 . [8093.375]
# [2.59143951 4.29600963 9.92058926 7.27019206 7.07648428 9.88620264
#  5.32217423 2.8871521 ] [61635.25] [[0.00291741 0.99708259]]
# [69728.625] [2.50007449 3.52562097 9.99156767 7.23879948 7.03351053 9.71711756
#  5.38327352 2.88655148] [[0.00218912 0.99781088]]
#
# No more feasible directions at iteration 0 . [0.]
# [9.46572723 8.31048572 9.53400387 8.08596509 8.53904379 8.14953446
#  2.57197839 2.32150929] [38359.5] [[0.17856321 0.82143679]]
# [38359.5] [9.46572723 8.31048572 9.53400387 8.08596509 8.53904379 8.14953446
#  2.57197839 2.32150929] [[0.17856321 0.82143679]]
#
# No more feasible directions at iteration 4098 . [38739.625]
# [4.20404871 6.23903807 9.53722911 4.87370122 5.62376644 8.01605349
#  3.50606934 3.87734483] [48286.125] [[0.09044017 0.90955983]]
# [87025.75] [ 3.76101988  2.50007473 10.00294697  4.83948362  5.48689344  7.23707995
#   3.69582191  3.88751466] [[0.02157849 0.97842151]]
#
# No more feasible directions at iteration 9297 . [46140.5]
# [5.25904766 8.20173937 7.41872267 8.21652658 2.64033946 8.93704144
#  9.65310424 5.90079695] [37010.75] [[0.40766783 0.59233217]]
# [83151.25] [4.85775492 2.50046812 8.69518449 7.8282839  2.5860981  9.06602292
#  9.78695712 5.75279967] [[0.01275669 0.98724331]]
#
# No more feasible directions at iteration 1760 . [24790.875]
# [7.55770164 4.50361243 8.21981413 9.34081355 7.3479328  6.0781645
#  8.63311071 5.71729505] [59825.625] [[0.27200781 0.72799219]]
# [84616.5] [7.3980725  2.50051318 8.57570557 9.24464382 7.32662376 5.71420779
#  8.71847701 5.642745  ] [[0.13413696 0.86586304]]
#
# No more feasible directions at iteration 2 . [0.625]
# [6.08199065 8.40358411 5.89640539 4.42759739 7.53155837 9.71729336
#  3.73004212 6.38113378] [37853.625] [[0.02548199 0.97451801]]
# [37854.25] [6.08199342 8.40359255 5.89660689 4.42760808 7.5315512  9.71749277
#  3.73002654 6.38114595] [[0.02547543 0.97452457]]
#
# No more feasible directions at iteration 1515 . [17863.5]
# [7.74386775 4.06369632 7.97899711 9.64484403 8.47690503 7.27085673
#  4.46140229 6.17626983] [58919.75] [[0.02170348 0.97829652]]
# [76783.25] [7.60391099 2.50041824 8.24934763 9.55401569 8.42100184 6.91521972
#  4.55749576 6.12820285] [[0.01219307 0.98780693]]
#
# No more feasible directions at iteration 8001 . [34327.375]
# [9.83432547 6.94863436 3.83738488 4.29967216 8.70712003 7.72073973
#  3.80252696 6.15572894] [34903.75] [[0.11283183 0.88716817]]
# [69231.125] [9.43333291 2.50097058 5.52253017 4.36627946 8.63195941 7.17300532
#  4.04439736 6.08457053] [[0.01147595 0.98852405]]
#
# No more feasible directions at iteration 1998 . [23525.875]
# [4.73444547 4.55713543 4.76768044 3.43126218 6.18119505 7.97143628
#  6.97046524 6.40215195] [52617.] [[0.04633888 0.95366112]]
# [76142.875] [4.54083728 2.5012385  5.32311635 3.40953348 6.14743079 7.73308523
#  7.06609006 6.35980687] [[0.01598226 0.98401774]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.15196124 4.35963291 9.26497618 7.90888302 2.78174951 5.73667108
#  4.98554116 7.05954161] [68057.25] [[0.37457274 0.62542726]]
# [68057.25] [2.15196124 4.35963291 9.26497618 7.90888302 2.78174951 5.73667108
#  4.98554116 7.05954161] [[0.37457274 0.62542726]]
#
# No more feasible directions at iteration 4461 . [33631.25]
# [9.64967842 5.9867215  3.45196606 3.87756789 6.47205822 6.1415491
#  2.61811839 4.86949291] [36840.875] [[0.53455729 0.46544271]]
# [70472.125] [9.36331454 2.50057669 4.74850469 3.90475357 6.49041356 5.6716284
#  2.75456603 4.86984799] [[0.1501156 0.8498844]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.41785327 8.26680725 4.55367652 4.91451848 5.77937036 9.39042502
#  2.42309088 4.50039664] [35139.375] [[0.07974718 0.92025282]]
# [35139.375] [2.41785327 8.26680725 4.55367652 4.91451848 5.77937036 9.39042502
#  2.42309088 4.50039664] [[0.07974718 0.92025282]]
#
# No more feasible directions at iteration 4517 . [35517.875]
# [3.3540051  6.14184468 4.14507689 7.70715658 5.39638998 8.50625557
#  5.5111194  9.66804906] [38016.5] [[0.03161526 0.96838474]]
# [73534.375] [3.11918705 2.5000307  5.42208448 7.38158282 5.31353956 8.32514517
#  5.63482443 9.4972875 ] [[0.00345673 0.99654327]]
#
# No more feasible directions at iteration 1 . [0.125]
# [6.412598   8.27427726 8.51503918 8.93291554 4.91323368 8.51247272
#  2.84247125 8.45886467] [38482.] [[0.08249137 0.91750863]]
# [38482.125] [6.41260246 8.2741645  8.51510572 8.93286981 4.91322516 8.51253009
#  2.84245165 8.45885221] [[0.08248014 0.91751986]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.27568762 5.53307114 2.17336102 5.82804661 9.9896783  9.04718562
#  9.71145997 9.88106918] [37632.75] [[0.00564042 0.99435958]]
# [37632.75] [2.27568762 5.53307114 2.17336102 5.82804661 9.9896783  9.04718562
#  9.71145997 9.88106918] [[0.00564042 0.99435958]]
#
# No more feasible directions at iteration 0 . [0.]
# [8.70381094 2.18843833 9.1430904  2.63586435 9.087634   8.09430626
#  6.82660793 3.75412987] [79882.] [[0.00457791 0.99542209]]
# [79882.] [8.70381094 2.18843833 9.1430904  2.63586435 9.087634   8.09430626
#  6.82660793 3.75412987] [[0.00457791 0.99542209]]
# No more feasible directions at iteration 5907 . [44795.5]
# [3.07421164 7.20075127 6.37380909 4.27023187 5.28944986 7.86059427
#  6.30914519 7.51564167] [39819.75] [[0.17285526 0.82714474]]
# [84615.25] [2.63884252 2.50018822 7.57694201 4.15281474 5.21459901 7.48489185
#  6.42165652 7.38295921] [[0.01374018 0.98625982]]
#
# No more feasible directions at iteration 351 . [200.5]
# [9.09445845 7.44103934 4.08270257 5.52141517 8.45846964 9.00860641
#  6.31020385 6.91349473] [35338.] [[0.04440207 0.95559793]]
# [35538.5] [9.09602563 7.39264381 4.14327577 5.52064915 8.46090375 9.04003972
#  6.31050215 6.90949568] [[0.04125168 0.95874832]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.24938549 7.1355691  9.60357587 6.03064032 9.55679646 9.94656893
#  5.29311738 3.4859656 ] [43081.75] [[0.00652788 0.99347212]]
# [43081.75] [2.24938549 7.1355691  9.60357587 6.03064032 9.55679646 9.94656893
#  5.29311738 3.4859656 ] [[0.00652788 0.99347212]]
#
# No more feasible directions at iteration 1191 . [17686.875]
# [3.47162806 3.8712053  4.81450869 7.01926862 4.67299764 6.82779323
#  4.26650141 3.42291838] [59196.875] [[0.22337033 0.77662967]]
# [76883.75] [3.36588849 2.5009554  5.21922399 6.94761477 4.66586175 6.64126121
#  4.33313456 3.41756079] [[0.12365772 0.87634228]]
#
# [4.20966833 4.82755058 8.33112372 6.05386772 6.45425962 7.42645223
#  9.66165679 9.32013025] [57937.] [[0.04242566 0.95757434]]
# [80951.625] [4.02780109 2.87364155 8.65371843 5.99023567 6.4076009  7.15146321
#  9.72469313 9.22120254] [[0.01701108 0.98298892]]
#
# No more feasible directions at iteration 4517 . [35517.875]
# [3.3540051  6.14184468 4.14507689 7.70715658 5.39638998 8.50625557
#  5.5111194  9.66804906] [38016.5] [[0.03161526 0.96838474]]
# [73534.375] [3.11918705 2.5000307  5.42208448 7.38158282 5.31353956 8.32514517
#  5.63482443 9.4972875 ] [[0.00345673 0.99654327]]
#
# No more feasible directions at iteration 0 . [0.]
# [4.39264145 2.27191115 2.46288536 3.14119009 3.8611725  6.42414569
#  6.1764177  6.65003673] [70693.875] [[0.14215701 0.85784299]]
# [70693.875] [4.39264145 2.27191115 2.46288536 3.14119009 3.8611725  6.42414569
#  6.1764177  6.65003673] [[0.14215701 0.85784299]]
#
# No more feasible directions at iteration 0 . [0.]
# [8.76154627 5.68712093 4.66332725 9.91320942 9.39240355 6.94184719
#  2.49427115 5.93361662] [39943.75] [[0.08239878 0.91760122]]
# [39943.75] [8.76154627 5.68712093 4.66332725 9.91320942 9.39240355 6.94184719
#  2.49427115 5.93361662] [[0.08239878 0.91760122]]
#
# No more feasible directions at iteration 36 . [17.875]
# [3.55884111 8.82054754 5.0221135  9.09558674 9.55597083 9.22706312
#  3.25523373 5.21691621] [34522.125] [[0.04113455 0.95886545]]
# [34540.] [3.56019109 8.82253334 5.02785423 9.09328862 9.5563612  9.23133187
#  3.25498786 5.21690397] [[0.04094845 0.95905155]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.77580922 3.72582298 2.45069058 8.23582683 9.28100114 6.83650414
#  4.17394074 6.97840703] [50780.125] [[0.02834051 0.97165949]]
# [50780.125] [2.77580922 3.72582298 2.45069058 8.23582683 9.28100114 6.83650414
#  4.17394074 6.97840703] [[0.02834051 0.97165949]]
#
# No more feasible directions at iteration 1515 . [17863.5]
# [7.74386775 4.06369632 7.97899711 9.64484403 8.47690503 7.27085673
#  4.46140229 6.17626983] [58919.75] [[0.02170348 0.97829652]]
# [76783.25] [7.60391099 2.50041824 8.24934763 9.55401569 8.42100184 6.91521972
#  4.55749576 6.12820285] [[0.01219307 0.98780693]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.18813213 2.9292535  9.03466641 7.78791587 3.77742236 6.61714789
#  2.36987329 4.4287817 ] [82082.375] [[0.07621508 0.92378492]]
# [82082.375] [2.18813213 2.9292535  9.03466641 7.78791587 3.77742236 6.61714789
#  2.36987329 4.4287817 ] [[0.07621508 0.92378492]]
#
# No more feasible directions at iteration 0 . [0.]
# [6.46193032 2.46136168 6.21853628 5.25788148 7.9013281  4.56285222
#  9.38669684 4.9114767 ] [85101.375] [[0.45833743 0.54166257]]
# [85101.375] [6.46193032 2.46136168 6.21853628 5.25788148 7.9013281  4.56285222
#  9.38669684 4.9114767 ] [[0.45833743 0.54166257]]
#
# No more feasible directions at iteration 1639 . [20820.125]
# [3.071609   4.24563298 5.1245792  7.19735674 6.06970858 7.5685513
#  4.64635842 9.32825589] [54772.125] [[0.0190335 0.9809665]]
# [75592.25] [2.93512764 2.50042656 5.61908671 7.08058112 6.02669841 7.34566305
#  4.71663821 9.25985778] [[0.00785209 0.99214791]]
#
# No more feasible directions at iteration 6 . [1.5]
# [4.97407362 8.85392438 9.0420079  3.11567614 3.9913667  9.06772489
#  5.74886625 5.50569836] [38549.125] [[0.2067907 0.7932093]]
# [38550.625] [4.97394507 8.85331052 9.04216424 3.11584732 3.99137575 9.06825719
#  5.74872694 5.50576951] [[0.20660918 0.79339082]]
#
# No more feasible directions at iteration 1813 . [10106.625]
# [2.59348001 5.82705433 3.91710052 4.40979897 7.12855959 7.86119938
#  2.97554615 9.19828572] [40819.125] [[0.02337265 0.97662735]]
# [50925.75] [2.50006025 4.59212598 4.43519867 4.34047965 7.10501496 7.79616585
#  3.00823453 9.15200113] [[0.01092181 0.98907819]]
#
# No more feasible directions at iteration 4176 . [33443.625]
# [3.03349873 5.98991279 7.60201447 2.65350567 6.81253481 9.09042745
#  2.53521989 7.94049156] [47183.375] [[0.00537574 0.99462426]]
# [80627.] [2.58751113 2.50036976 8.21152371 2.64911089 6.60990868 8.45690626
#  2.71406409 7.88430465] [[0.00120486 0.99879514]]
#
# No more feasible directions at iteration 1914 . [18517.25]
# [5.85864825 4.2843192  6.14918803 6.69545209 5.19060212 9.4347719
#  3.21813603 3.40114842] [53785.375] [[0.01087627 0.98912373]]
# [72302.625] [5.6769512  2.50020813 6.55379872 6.62931906 5.1170592  9.12781333
#  3.35476798 3.41790765] [[0.00485249 0.99514751]]
#
# Non greedy step
# Non greedy step
# [8.80520968 2.50792814 8.8845873  9.7151944  9.88507815 3.43088659
#  2.56398478 7.8957911 ] [84950.375] [[0.18172691 0.81827309]]
# [84988.375] [8.80498629 2.50530819 8.88503949 9.71506544 9.88502365 3.43019123
#  2.56409428 7.89568234] [[0.18159673 0.81840327]]
#
# No more feasible directions at iteration 2824 . [34906.125]
# [3.21984115 5.39741914 3.06195252 3.71725886 3.17636821 6.49714444
#  4.97751651 3.937595  ] [40994.5] [[0.68760074 0.31239926]]
# [75900.625] [3.00499652 2.50023947 4.12797564 3.64341541 3.21650732 6.30090261
#  5.06562088 3.94274683] [[0.26655091 0.73344909]]
#
# No more feasible directions at iteration 18 . [11.]
# [6.39951632 9.79564212 7.35208721 9.51407639 6.46764197 8.22852305
#  8.03919005 9.79319301] [34911.5] [[0.27523274 0.72476726]]
# [34922.5] [6.40040471 9.7975372  7.35358993 9.51315212 6.46805614 8.23179453
#  8.0382959  9.79253688] [[0.27464148 0.72535852]]
#
# No more feasible directions at iteration 1813 . [10106.625]
# [2.59348001 5.82705433 3.91710052 4.40979897 7.12855959 7.86119938
#  2.97554615 9.19828572] [40819.125] [[0.02337265 0.97662735]]
# [50925.75] [2.50006025 4.59212598 4.43519867 4.34047965 7.10501496 7.79616585
#  3.00823453 9.15200113] [[0.01092181 0.98907819]]
#
# No more feasible directions at iteration 0 . [0.]
# [3.57861903 6.280178   8.65911151 9.68024777 5.08156352 7.32347276
#  7.9498362  2.06146579] [47244.75] [[0.51559416 0.48440584]]
# [47244.75] [3.57861903 6.280178   8.65911151 9.68024777 5.08156352 7.32347276
#  7.9498362  2.06146579] [[0.51559416 0.48440584]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.27568762 5.53307114 2.17336102 5.82804661 9.9896783  9.04718562
#  9.71145997 9.88106918] [37632.75] [[0.00564042 0.99435958]]
# [37632.75] [2.27568762 5.53307114 2.17336102 5.82804661 9.9896783  9.04718562
#  9.71145997 9.88106918] [[0.00564042 0.99435958]]
#
# No more feasible directions at iteration 0 . [0.]
# [4.31666012 3.86802621 2.32225016 2.61348146 6.03567236 4.31940999
#  5.86434536 9.52098839] [52447.875] [[0.55991851 0.44008149]]
# [52447.875] [4.31666012 3.86802621 2.32225016 2.61348146 6.03567236 4.31940999
#  5.86434536 9.52098839] [[0.55991851 0.44008149]]
#
# No more feasible directions at iteration 0 . [0.]
# [4.91825354 8.84363622 8.66625149 2.02358779 9.74090145 9.86560545
#  7.37689289 9.83481264] [37677.625] [[0.00626227 0.99373773]]
# [37677.625] [4.91825354 8.84363622 8.66625149 2.02358779 9.74090145 9.86560545
#  7.37689289 9.83481264] [[0.00626227 0.99373773]]
#
# [3.20978778 5.61620938 6.28397452 7.22049742 4.15747764 5.30598582
#  7.07260903 9.02065844] [47713.125] [[0.64734937 0.35265063]]
# [47713.125] [3.20978778 5.61620938 6.28397452 7.22049742 4.15747764 5.30598582
#  7.07260903 9.02065844] [[0.64734937 0.35265063]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.32452262 2.58871554 9.32749721 9.99315489 4.52452962 7.02169385
#  4.2840132  2.97129558] [85464.] [[0.05962778 0.94037222]]
# [85464.] [2.32452262 2.58871554 9.32749721 9.99315489 4.52452962 7.02169385
#  4.2840132  2.97129558] [[0.05962778 0.94037222]]
#
# No more feasible directions at iteration 0 . [0.]
# [7.53381978 5.0247256  4.36767679 2.42057232 8.78170563 6.50598406
#  6.48295633 9.8428026 ] [45592.75] [[0.06602027 0.93397973]]
# [45592.75] [7.53381978 5.0247256  4.36767679 2.42057232 8.78170563 6.50598406
#  6.48295633 9.8428026 ] [[0.06602027 0.93397973]]
#
# No more feasible directions at iteration 59 . [31.875]
# [5.49215417 8.26276766 6.21403859 8.44036831 9.6772564  6.78353181
#  2.86848029 5.2141351 ] [35755.875] [[0.31939203 0.68060797]]
# [35787.75] [5.49307842 8.25393922 6.22364263 8.43759055 9.6783605  6.78560358
#  2.86783763 5.21368762] [[0.31725705 0.68274295]]
#
# No more feasible directions at iteration 0 . [0.]
# [4.84788685 8.63168772 8.61044395 2.18168394 8.05187205 5.55607202
#  2.35807409 7.83784001] [38127.5] [[0.56895072 0.43104928]]
# [38127.5] [4.84788685 8.63168772 8.61044395 2.18168394 8.05187205 5.55607202
#  2.35807409 7.83784001] [[0.56895072 0.43104928]]
#
# No more feasible directions at iteration 28 . [517.25]
# [8.35167157 2.53638853 3.62191849 5.94652202 3.26035179 5.44623108
#  7.99273296 3.63119396] [70164.375] [[0.71167899 0.28832101]]
# [70681.625] [8.34911816 2.50035384 3.63303916 5.94566923 3.26080497 5.44222277
#  7.99413693 3.63079055] [[0.70754981 0.29245019]]
#
# No more feasible directions at iteration 4 . [1.125]
# [4.24420862 9.87886603 9.85150662 9.96195105 6.38345437 6.98902191
#  3.50112154 8.66333995] [36233.625] [[0.44212496 0.55787504]]
# [36234.75] [4.24433101 9.87899204 9.85165741 9.96170812 6.38350568 6.98938831
#  3.50092648 8.66324658] [[0.44202687 0.55797313]]
# Non greedy step
# Non greedy step
# Non greedy step
# Non greedy step
# Non greedy step
# [3.0885825  7.34552638 5.19000697 2.65042012 8.70100458 8.68577093
#  7.85250398 8.18927875] [37615.625] [[0.03303762 0.96696238]]
# [72686.125] [2.65860044 3.05978309 6.44782432 2.64323302 8.60356743 8.4692395
#  7.99807322 7.99079919] [[0.00251886 0.99748114]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.0492438  3.76322981 5.37982854 5.86245733 4.71079861 5.4551199
#  6.22584348 9.5382352 ] [64807.625] [[0.23543077 0.76456923]]
# [64807.625] [2.0492438  3.76322981 5.37982854 5.86245733 4.71079861 5.4551199
#  6.22584348 9.5382352 ] [[0.23543077 0.76456923]]
#
# No more feasible directions at iteration 9297 . [46140.5]
# [5.25904766 8.20173937 7.41872267 8.21652658 2.64033946 8.93704144
#  9.65310424 5.90079695] [37010.75] [[0.40766783 0.59233217]]
# [83151.25] [4.85775492 2.50046812 8.69518449 7.8282839  2.5860981  9.06602292
#  9.78695712 5.75279967] [[0.01275669 0.98724331]]
#
# No more feasible directions at iteration 260 . [4031.75]
# [7.69025148 2.81017694 7.48039875 7.10897734 7.33196814 6.50889107
#  4.53468652 6.53750297] [73999.] [[0.03274591 0.96725409]]
# [78030.75] [7.6607194  2.50079729 7.53797157 7.09947589 7.32302716 6.44267706
#  4.55124056 6.52946661] [[0.02906507 0.97093493]]
#
# Non greedy step
# Non greedy step
# Non greedy step
# [3.0885825  7.34552638 5.19000697 2.65042012 8.70100458 8.68577093
#  7.85250398 8.18927875] [37615.625] [[0.03303762 0.96696238]]
# [72657.5] [2.65885029 3.06208305 6.44737053 2.64325017 8.60364727 8.46960456
#  7.99795017 7.99087823] [[0.00252153 0.99747847]]
#
# No more feasible directions at iteration 1998 . [23525.875]
# [4.73444547 4.55713543 4.76768044 3.43126218 6.18119505 7.97143628
#  6.97046524 6.40215195] [52617.] [[0.04633888 0.95366112]]
# [76142.875] [4.54083728 2.5012385  5.32311635 3.40953348 6.14743079 7.73308523
#  7.06609006 6.35980687] [[0.01598226 0.98401774]]
#
# No more feasible directions at iteration 3365 . [30119.375]
# [4.98997542 5.41873414 3.61500436 6.05701488 8.23160727 7.29218542
#  3.97855472 9.33913974] [40925.25] [[0.03267511 0.96732489]]
# [71044.625] [4.77571732 2.50001643 4.64266738 5.89129779 8.17612211 6.95037936
#  4.09384599 9.20858798] [[0.00701982 0.99298018]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.77580922 3.72582298 2.45069058 8.23582683 9.28100114 6.83650414
#  4.17394074 6.97840703] [50780.125] [[0.02834051 0.97165949]]
# [50780.125] [2.77580922 3.72582298 2.45069058 8.23582683 9.28100114 6.83650414
#  4.17394074 6.97840703] [[0.02834051 0.97165949]]
#
# No more feasible directions at iteration 1430 . [16137.125]
# [3.29835214 3.93847072 5.76595876 8.42154026 8.73202246 8.79435178
#  4.57508597 9.83259606] [55803.875] [[0.00123864 0.99876136]]
# [71941.] [3.17611674 2.50093018 6.11905223 8.30586744 8.66491479 8.55705841
#  4.66013313 9.76243752] [[6.47486007e-04 9.99352514e-01]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.42158645 5.36692403 4.19314939 9.88923386 3.3281671  7.72567782
#  2.5713273  4.58021405] [41333.625] [[0.1941387 0.8058613]]
# [41333.625] [2.42158645 5.36692403 4.19314939 9.88923386 3.3281671  7.72567782
#  2.5713273  4.58021405] [[0.1941387 0.8058613]]
#
# No more feasible directions at iteration 73 . [33.125]
# [7.82541368 9.05357745 6.12543613 3.78607311 3.17592024 8.90417857
#  5.31863657 7.15969502] [36594.5] [[0.32269258 0.67730742]]
# [36627.625] [7.8264196  9.05685392 6.13329754 3.78760519 3.17718068 8.91663885
#  5.31591627 7.16023924] [[0.3194656 0.6805344]]
#
# No more feasible directions at iteration 1835 . [24541.75]
# [4.00903864 4.51987833 7.80549751 8.69561418 8.49851633 6.60813089
#  4.9609437  8.97707959] [58127.375] [[0.02771196 0.97228804]]
# [82669.125] [3.83856451 2.50119598 8.2040179  8.56086212 8.43979418 6.21614146
#  5.04477485 8.88088981] [[0.01208717 0.98791283]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.0492438  3.76322981 5.37982854 5.86245733 4.71079861 5.4551199
#  6.22584348 9.5382352 ] [64807.625] [[0.23543077 0.76456923]]
# [64807.625] [2.0492438  3.76322981 5.37982854 5.86245733 4.71079861 5.4551199
#  6.22584348 9.5382352 ] [[0.23543077 0.76456923]]
#
# No more feasible directions at iteration 0 . [0.]
# [4.39264145 2.27191115 2.46288536 3.14119009 3.8611725  6.42414569
#  6.1764177  6.65003673] [70693.875] [[0.14215701 0.85784299]]
# [70693.875] [4.39264145 2.27191115 2.46288536 3.14119009 3.8611725  6.42414569
#  6.1764177  6.65003673] [[0.14215701 0.85784299]]
#
# No more feasible directions at iteration 36 . [17.875]
# [3.55884111 8.82054754 5.0221135  9.09558674 9.55597083 9.22706312
#  3.25523373 5.21691621] [34522.125] [[0.04113455 0.95886545]]
# [34540.] [3.56019109 8.82253334 5.02785423 9.09328862 9.5563612  9.23133187
#  3.25498786 5.21690397] [[0.04094845 0.95905155]]
#
# No more feasible directions at iteration 4050 . [34022.]
# [5.109143   5.87968232 2.62457319 4.73146964 4.27903775 8.8700357
#  8.53360342 4.26528994] [37294.75] [[0.18534504 0.81465496]]
# [71316.75] [4.86528313 2.5003003  3.90675496 4.63918092 4.29323988 8.83722636
#  8.69875294 4.24808922] [[0.02198692 0.97801308]]
#
# No more feasible directions at iteration 0 . [0.]
# [6.46193032 2.46136168 6.21853628 5.25788148 7.9013281  4.56285222
#  9.38669684 4.9114767 ] [85101.375] [[0.45833743 0.54166257]]
# [85101.375] [6.46193032 2.46136168 6.21853628 5.25788148 7.9013281  4.56285222
#  9.38669684 4.9114767 ] [[0.45833743 0.54166257]]
#
# No more feasible directions at iteration 0 . [0.]
# [6.41370253 3.84796082 6.6787151  4.50722332 2.41903965 5.59174267
#  3.64566932 3.20541394] [64869.5] [[0.68471477 0.31528523]]
# [64869.5] [6.41370253 3.84796082 6.6787151  4.50722332 2.41903965 5.59174267
#  3.64566932 3.20541394] [[0.68471477 0.31528523]]
#
# No more feasible directions at iteration 1831 . [23699.125]
# [5.5656446  4.48493532 9.23656697 7.38481998 7.2770088  6.54463189
#  2.93160599 9.79820983] [59921.625] [[0.02226226 0.97773774]]
# [83620.75] [5.36685328 2.50079174 9.52842296 7.29651154 7.19439709 6.0944694
#  3.00904263 9.71378249] [[0.0107866 0.9892134]]
#
# No more feasible directions at iteration 107 . [1710.875]
# [7.80140724 2.62842748 5.54328779 9.13336153 7.01419669 5.73058897
#  4.2462284  6.93044481] [71372.25] [[0.08863983 0.91136017]]
# [73083.125] [7.79192024 2.50027465 5.57683093 9.12584258 7.01231531 5.70711578
#  4.25236638 6.92645496] [[0.08410689 0.91589311]]
#
# No more feasible directions at iteration 0 . [0.]
# [2.15196124 4.35963291 9.26497618 7.90888302 2.78174951 5.73667108
#  4.98554116 7.05954161] [68057.25] [[0.37457274 0.62542726]]
# [68057.25] [2.15196124 4.35963291 9.26497618 7.90888302 2.78174951 5.73667108
#  4.98554116 7.05954161] [[0.37457274 0.62542726]]
#
# No more feasible directions at iteration 0 . [0.]
# [7.06856866 2.21573269 6.34825617 7.88644084 7.55687063 9.58805763
#  3.48553571 3.46890728] [70692.75] [[0.00117335 0.99882665]]
# [70692.75] [7.06856866 2.21573269 6.34825617 7.88644084 7.55687063 9.58805763
#  3.48553571 3.46890728] [[0.00117335 0.99882665]]
#
# [4.20966833 4.82755058 8.33112372 6.05386772 6.45425962 7.42645223
#  9.66165679 9.32013025] [57937.] [[0.04242566 0.95757434]]
# [80951.625] [4.02780109 2.87364155 8.65371843 5.99023567 6.4076009  7.15146321
#  9.72469313 9.22120254] [[0.01701108 0.98298892]]
#
# BEST [94059.75]

# %%
samples = filtered_df.iloc[np.random.choice(len(filtered_df), 197), :8]
best = 0
for i in range(197):
    X0 = np.array(samples.iloc[i])
    result = coordinateAscentNN(q_classifier, qr, X0, confidence = .6)
    print(X0, qr.predict(poly.fit_transform([X0])), reg.predict_proba([X0])) #q_classifier.predict_proba(poly.fit_transform([x0])))
    print(qr.predict(poly.fit_transform([result])), result, reg.predict_proba([result]))
    print()
    best = max(best, qr.predict(poly.fit_transform([result]))
print('BEST', best)
# Out:
#        Schord     Sspan    Ssweep      Stip    Bchord     Bspan    Bsweep  \
# 1    5.050903  2.807665  7.250966  4.202998  7.871765  6.329711  3.563606
# 2    8.796076  5.131824  8.469040  8.168441  6.226139  7.792487  6.816335
# 5    8.562160  4.337768  7.930397  4.372560  9.417980  8.246008  2.728282
# 6    8.703811  2.188438  9.143090  2.635864  9.087634  8.094306  6.826608
# 8    8.074672  3.479253  5.061755  2.201202  8.430403  6.003352  2.080965
# ..        ...       ...       ...       ...       ...       ...       ...
# 393  5.247843  7.799644  8.441005  9.658211  6.937770  7.882306  6.353957
# 395  2.608430  3.346465  5.201403  9.166944  6.192108  3.850187  7.960717
# 396  7.801407  2.628427  5.543288  9.133362  7.014197  5.730589  4.246228
# 398  7.094305  2.423077  2.934079  6.637124  4.526698  3.664447  4.901074
# 399  3.451784  3.164933  3.213005  9.450705  8.759146  8.331735  2.206001
#
#          Btip  Schordspan  Schordsweep  ...  SSweeptip  Bchordspan  \
# 1    6.148326   14.181241    36.623926  ...  30.475799   49.826002
# 2    8.795342   45.139920    74.494323  ...  69.178850   48.517110
# 5    6.326085   37.140668    67.901332  ...  34.676133   77.660732
# 6    3.754130   19.047753    79.579730  ...  24.099946   73.558093
# 8    3.394916   28.093824    40.872014  ...  11.141944   50.610675
# ..        ...         ...          ...  ...        ...         ...
# 393  9.196173   40.931306    44.297067  ...  81.524999   54.685626
# 395  8.586406    8.729021    13.567499  ...  47.680974   23.840776
# 396  6.930445   20.505433    43.245446  ...  50.628851   40.195478
# 398  5.327160   17.190049    20.815255  ...  19.473850   16.587847
# 399  6.427374   10.924665    11.090597  ...  30.365158   72.978885
#
#      Bchordsweep  Bchordtip  Bspansweep   BSpantip  BSweeptip  Altitude  \
# 1      28.051867  48.398181   22.556595  38.917130  21.910210  77117.16
# 2      42.439452  54.761021   53.116208  68.537590  59.951999  51216.00
# 5      25.694900  59.578937   22.497430  52.164942  17.259340  54082.50
# 6      62.037714  34.116158   55.256655  30.387077  25.627973  78784.51
# 8      17.543371  28.620512   12.492762  20.380874   7.064700  59576.45
# ..           ...        ...         ...        ...        ...       ...
# 393    44.082290  63.800932   50.083829  72.487046  58.432082  39893.78
# 395    49.293623  53.167952   30.650253  33.059270  68.353950  70830.75
# 396    29.783881  48.611503   24.333390  39.715531  29.428252  72485.31
# 398    22.185683  24.114444   17.959727  19.521095  26.108803  73446.17
# 399    19.322682  56.298306   18.379814  53.551178  14.178791  55933.92
#
#      Stability      Time
# 1     1.278655  154.9973
# 2     5.212006  125.0071
# 5     4.485508  129.0079
# 6     0.613785  156.9962
# 8     2.920013  136.0078
# ..         ...       ...
# 393   5.851534  111.0041
# 395   1.673402  149.0006
# 396   1.614970  150.9995
# 398   0.853824  150.9995
# 399   2.408665  131.0084
#
# [197 rows x 23 columns]

# %%
(np.array([1798.5480936491524, 1674.2732111008672, 1794.2786856643647]) + np.array([3868.141600677256, 1899.4293720457517, 2055.44657284463]) + np.array([2198.368013197518, 1577.0980127111864, 1648.1305938586702]) + np.array([1815.417729777189, 2056.5256021326427, 1815.019990798251]))/4
# Out:
# array([2420.11885933, 1801.8315495 , 1828.21896079])
